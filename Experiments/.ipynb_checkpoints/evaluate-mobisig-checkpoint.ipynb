# %%
import numpy as np
import pandas as pd
import math
from math import sin, cos, radians
import random
import re

import os
import matplotlib.pyplot as plt
import datetime

import scipy.stats as st
import scipy.signal as sgl
pd.set_option('display.max_columns', 500)

#import fastdtw
from scipy.spatial.distance import euclidean
from fastdtw import fastdtw

import scipy.interpolate as spi

#hide warning
import warnings
warnings.filterwarnings('ignore')

# %%
# remove_duplicated_point
def remove_duplicated_point(df):
    df_new = df.drop(index=df.index)    
    old_x = df['X'][0]
    old_y = df['Y'][0]
    for index, row in df.iterrows():
        if row['X'] != old_x or row['Y']!=old_y or index == 0:
            df_new.loc[len(df_new)] = {'X': row['X'], 'Y': row['Y'], 'TStamp': row['TStamp'], 'Pres': row['Pres'], 'EndPts': row['EndPts'],
                                       'TStamp2': row['TStamp2']}
            old_x = row['X']
            old_y = row['Y']
        # update the EndPts if the point is   
        elif row['X'] == old_x and row['Y'] == old_y and row['EndPts'] == 1:
            df_new.iloc[len(df_new)-1]['EndPts']  = 1
    return df_new

# %%
# Size normalization 大小规整
# position normalization 位置规整
def normalizeFile(normalInputFile):
    widthX = 400 #width
    heightY = 300 #height
    minX = normalInputFile['X'].min()
    minY = normalInputFile['Y'].min()
    maxX = normalInputFile['X'].max()
    maxY = normalInputFile['Y'].max()
    normalInputFile['normalX'] = widthX * ((normalInputFile['X'] - minX)/(maxX - minX))
    normalInputFile['normalY'] = heightY * ((normalInputFile['Y'] - minY)/(maxY - minY))
    
    #position normalization
    averX = normalInputFile['normalX'].mean()
    averY = normalInputFile['normalY'].mean()

    normalInputFile['normalX'] = normalInputFile['normalX'] - averX
    normalInputFile['normalY'] = normalInputFile['normalY'] - averY
    
#     normalInputFile['Angle'] = 0.0
#     normalInputFile['Vel'] = 0.0
#     normalInputFile['Logcr'] = 0.0
#     normalInputFile['Tam'] = 0.0
    return normalInputFile


#length normalization
def samelen(data,length=400):
    data_size = len(data)
    interval = (data_size-1)/length
    start = 0
    new_data = data.drop(index=data.index)
    for dist in np.arange(start, data_size-1, interval):
        first = math.floor(dist)
        second = math.ceil(dist)
        if second >= data_size:
            second = data_size -1
        percent = (dist - first) / 1.0   
        #'X','Y','TStamp','Pres','EndPts'
#         print ((data.X[first] + data.X[second])/2)

#         X = (data.at[first,'X'] + data.at[second,'X']) / 2
#         Y = (data.Y[first] + data.Y[second])/2 
        TStamp = (data.TStamp[first] + data.TStamp[second])/2 
        
        X = data.at[first,'X'] + (data.at[second,'X'] - data.at[first,'X']) * percent
        Y = data.at[first,'Y'] + (data.at[second,'Y'] - data.at[first,'Y']) * percent
        normalX = data.at[first,'normalX'] + (data.at[second,'normalX'] - data.at[first,'normalX']) * percent
        normalY = data.at[first,'normalY'] + (data.at[second,'normalY'] - data.at[first,'normalY']) * percent 
        TStamp2 = data.at[first,'TStamp2'] + (data.at[second,'TStamp2'] - data.at[first,'TStamp2']) * percent 
        Pres = data.at[first,'Pres'] + (data.at[second,'Pres'] - data.at[first,'Pres']) * percent 
        Angle = data.at[first,'Angle'] + (data.at[second,'Angle'] - data.at[first,'Angle']) * percent
        Vel = data.at[first,'Vel'] + (data.at[second,'Vel'] - data.at[first,'Vel']) * percent 
        Logcr = data.at[first,'Logcr'] + (data.at[second,'Logcr'] - data.at[first,'Logcr']) * percent 
        Tam = data.at[first,'Tam'] + (data.at[second,'Tam'] - data.at[first,'Tam']) * percent 
        
        d_X = data.at[first,'d_X'] + (data.at[second,'d_X'] - data.at[first,'d_X']) * percent
        d_Y = data.at[first,'d_Y'] + (data.at[second,'d_Y'] - data.at[first,'d_Y']) * percent 
        d_Angle = data.at[first,'d_Angle'] + (data.at[second,'d_Angle'] - data.at[first,'d_Angle']) * percent
        d_Vel = data.at[first,'d_Vel'] + (data.at[second,'d_Vel'] - data.at[first,'d_Vel']) * percent 
        d_Logcr = data.at[first,'d_Logcr'] + (data.at[second,'d_Logcr'] - data.at[first,'d_Logcr']) * percent 
        d_Tam = data.at[first,'d_Tam'] + (data.at[second,'d_Tam'] - data.at[first,'d_Tam']) * percent 
        
        if data.EndPts[first] == 1 or data.EndPts[second] == 1:
            EndPts = 1
        else:
            EndPts = 0
            
        new_data.loc[len(new_data)] = {'X': X, 'Y': Y, 'TStamp': TStamp, 'Pres': Pres, 'EndPts': EndPts,'normalX': normalX,
                         'normalY': normalY, 'TStamp2': TStamp2,'Angle': Angle,'Vel': Vel,'Logcr': Logcr,'Tam': Tam,
                         'd_X': d_X, 'd_Y': d_Y,'d_Angle': d_Angle,'d_Vel': d_Vel,'d_Logcr': d_Logcr,'d_Tam': d_Tam,} 
    return new_data

# %%
"""
    add new features to signals
"""

def addSigFeature(df):
    dX = derivation(df['X'].tolist())     # dx
    dY = derivation(df['Y'].tolist())     # dy
#     df['dX'] = dX
#     df['dY'] = dY
    Vel = np.zeros(len(df)).tolist()   # velocity
    Angle = np.zeros(len(df)) # angle
    
    
    T = len(df) -1
    t = 1
    while t<= T:
        Vel[t] = math.sqrt(dX[t] * dX[t] + dY[t] * dY[t])
        if dY[t] != 0 and dX[t] != 0:
            Angle[t] = math.atan(dY[t] / dX[t])
        elif dX[t] == 0:
            Angle[t] = math.atan(dY[t] / 0.01)
        else:
            Angle[t] = 0
        t += 1    
    dAngle = derivation(Angle)
    dVel = derivation(Vel)
    Logcr = np.zeros(len(df)).tolist() 
    Tam = np.zeros(len(df)).tolist() #加速度 acceleration
    
    t = 1
    while t<= T:
        Logcr[t] = math.log((abs(Vel[t]) + 0.01) / ((abs(dAngle[t]) + 0.01))) ;
        Tam[t] = math.sqrt(dVel[t] * dVel[t] + Vel[t] * Vel[t] * dAngle[t] * dAngle[t]) ;
        t += 1
    df['Angle'] = Angle
    df['Vel'] = Vel
    df['Logcr'] = Logcr
    df['Tam'] = Tam
    return df
    
    
# calculate the difference of the discrete sequence    
def derivation(signal):
    T = len(signal)-1
    dsignal = np.zeros(len(signal)).tolist()
    dsignal[0] = (2*signal[2] + signal[1] - 3*signal[0]) / 5
    dsignal[1] = (2*signal[3] + signal[2] - 2*signal[1] - signal[0]) / 6
    t= 2
    while t<=T-2:
        dsignal[t] = (2*signal[t+2] + signal[t+1] - signal[t-1] - 2*signal[t-2]) / 10 
#         print(dsignal[t])        
        t += 1
        # (2(Xn+2)+(Xn+1)-(Xn-1)-2(Xn-2))/10 == [2(Xn+2)-2(Xn+1)+3(Xn+1)-3(Xn)+3(Xn)-3(Xn-1)+2(Xn-1)-2(Xn-2)]/10
        
    dsignal[T-1] = (signal[T] - signal[T-2] + 2*signal[T-1] - 2*signal[T-3]) / 6 
    dsignal[T] = (3*signal[T] - signal[T-1] - 2*signal[T-2]) / 5 
    return dsignal

# calculate the first order derivation for all 6 features   
def addFirstOrderDerivation(df):
    d_X = derivation(df['X'].tolist())     
    d_Y = derivation(df['Y'].tolist())     
    d_Angle = derivation(df['Angle'].tolist())   
    d_Vel = derivation(df['Vel'].tolist())   
    d_Logcr = derivation(df['Logcr'].tolist())   
    d_Tam = derivation(df['Tam'].tolist())   
    
    df['d_X'] = d_X
    df['d_Y'] = d_Y
    df['d_Angle'] = d_Angle
    df['d_Vel'] = d_Vel 
    df['d_Logcr'] = d_Logcr 
    df['d_Tam'] = d_Tam     
    return df

# %%
#preprocessing
def preprocess(df, length=400):
    startTime = df['TStamp'][0]
    df['TStamp2'] = (df['TStamp'] - startTime) #ms
#     df['EndPts'][len(df)-1] = 1
#     print(df)
#     df = rdp_precoss(df) # use RDP algorithm to remove duplicated points
#     df = interpolate_points(df)
    df = remove_duplicated_point(df)  
    df = addEmptyFeature(df) 
    df = addSigFeature(df)
    df = addFirstOrderDerivation(df)    
    df = normalizeFile(df)
    #     df = rotate_graphic(df)    
    
    df = samelen(df, length)
    df = normalization_df(df)   
    return df

def get_ts(df):
    normalX = np.array(df['normalX'])
    normalY = np.array(df['normalY'])
    X = np.array(df['X'])
    Y = np.array(df['Y'])    
    Pres = np.array(df['Pres'])
    Angle = np.array(df['Angle'])
    Vel = np.array(df['Vel'])
    Logcr = np.array(df['Logcr'])
    Tam = np.array(df['Tam'])
    
    d_X = np.array(df['d_X'])
    d_Y = np.array(df['d_Y'])
    d_Angle = np.array(df['d_Angle'])
    d_Vel = np.array(df['d_Vel'])
    d_Logcr = np.array(df['d_Logcr'])
    d_Tam = np.array(df['d_Tam'])    
    
#     ts = np.array(list(zip(normalX,normalY,Angle,Vel,Logcr,Tam)),dtype=float)    
    ts = np.array(list(zip(normalX,normalY,Angle,Vel,Logcr,Tam,d_X,d_Y,d_Angle,d_Vel,d_Logcr,d_Tam)),dtype=float) 
 
    return ts

def cal_dfs_max_length(path, files):
    max_length = 0
    for fname in files:
        with open(path + '/' + fname,'rb') as f:
            count = 0
            last_data = '\n'
            while True:
                data = f.read(0x400000)
                if not data:
                    break
                count += data.count(b'\n')
                last_data = data
            if last_data[-1:] != b'\n':
                count += 1 # Remove this if a wc-like count is needed        
        length = count
        if length > max_length:
            max_length = length
    print(max_length-1)        
    return max_length-1  

def normalization_df(df):
    TStamp2 = df['TStamp2'].tolist()
    TStamp = df['TStamp'].tolist()
    normalized_df=(df-df.mean())/df.std()
#     normalized_df=(df-df.min())/(df.max()-df.min())
    normalized_df['TStamp2'] = TStamp2
    normalized_df['TStamp'] = TStamp
    return normalized_df

def addEmptyFeature(df):
    df['d_X'] = 0
    df['d_Y'] = 0
    df['d_Angle'] = 0
    df['d_Vel'] = 0 
    df['d_Logcr'] = 0 
    df['d_Tam'] = 0
    return df

# %%
# read dataset

base_path_forg = 'dataset/mobisig' #FROM FILE PATH
base_path_genu = 'dataset/mobisig' #FROM FILE PATH
save_base_path_forg = 'dataset/mobisig/preprocessed/' #SAVE FILE PATH
save_base_path_genu = 'dataset/mobisig/preprocessed/' #SAVE FILE PATH

DEBUG_MODE = True
TOTAL_NUM = 0.0
TOTAL_GENU = 0.0
TOTAL_FORG = 0.0
TOTAL_FN = 0.0
TOTAL_FP = 0.0
TOTAL_ACCU = 0.0
TRAINING_SET_SIZE = 3
FEATRUE_NUM = 3
counter = 1

while (counter<84): 
# while (counter<2):     
    base1_genu = 'SIGN_GEN_USER'
    base1_forg = 'SIGN_FOR_USER'
        
    genuinefiles = []
    forgeryfiles = []
        
    #get genuine signature    
    for root, dirs, files in os.walk(base_path_genu + '/USER' + str(counter)):
        for f in files:
            if f.startswith(base1_genu + str(counter)):
                genuinefiles = np.append(genuinefiles,f)
                genuinefiles = list(genuinefiles)
    print(genuinefiles)
    #get forgery signature    
    for root, dirs, files in os.walk(base_path_forg + '/USER' + str(counter)):
        for f in files:
            if f.startswith(base1_forg + str(counter)):
                forgeryfiles = np.append(forgeryfiles,f)
                forgeryfiles = list(forgeryfiles)
    if len(genuinefiles) == 0:
        counter += 1
        continue
        
    # feature extraction , preprocessing and save
    dfs_max_length = cal_dfs_max_length(base_path_genu + '/USER' + str(counter), genuinefiles)
    for f in genuinefiles:
        temp = str(base_path_genu+ '/USER' + str(counter) + '/' +f)
        df = pd.read_csv(temp,delimiter=',', header=0, names=['X', 'Y','TStamp','Pres'], usecols=[0,1,2,3])
        df['EndPts'] = 0       
        df = preprocess(df,dfs_max_length)
        temp = str(save_base_path_genu+ '/USER' + str(counter) + '/' +f)
        if not os.path.exists(save_base_path_genu+ '/USER'+ str(counter)):
            os.mkdir(save_base_path_genu+ '/USER'+ str(counter))
        df.to_csv(temp,sep=" ",header=True, index= False)
    
    for f in forgeryfiles:
        temp = str(base_path_forg+ '/USER' + str(counter) + '/' +f)
        df = pd.read_csv(temp,delimiter=',', header=0, names=['X', 'Y','TStamp','Pres'], usecols=[0,1,2,3])
        df['EndPts'] = 0      
        df = preprocess(df,dfs_max_length)   
        temp = str(save_base_path_genu+ '/USER' + str(counter) + '/' +f)
        df.to_csv(temp,sep=" ",header=True, index= False)
        
    
    # X Y TStamp Pres EndPts TStamp2 Angle Vel Logcr Tam normalX normalY d_normalX d_normalY d_Angle d_Vel d_Logcr d_Tam
    counter += 1

# %%
# read dataset

base_path_forg = 'dataset/mobisig/preprocessed' #FROM FILE PATH
base_path_genu = 'dataset/mobisig/preprocessed' #FROM FILE PATH


DEBUG_MODE = True
TOTAL_NUM = 0.0
TOTAL_GENU = 0.0
TOTAL_FORG = 0.0
TOTAL_FN = 0.0
TOTAL_FP = 0.0
TOTAL_ACCU = 0.0
TRAINING_SET_SIZE = 3
FEATRUE_NUM = 6
FILE_FEATURE_NAMES = ['X','Y','TStamp','Pres','EndPts','TStamp2','d_X','d_Y','d_Angle','d_Vel','d_Logcr','d_Tam',
                      'Angle','Vel','Logcr','Tam','normalX','normalY']
counter = 1

while (counter<84):    
    base1_genu = 'SIGN_GEN_USER'
    base1_forg = 'SIGN_FOR_USER'
        
    genuinefiles = []
    forgeryfiles = []
        

    #get genuine signature    
    #SIGN_GEN_USER11_USER11_1
    genuinefiles_session1_tmp = []
    genuinefiles_session1 = []
    for root, dirs, files in os.walk(base_path_genu + '/USER' + str(counter)):
        for f in files:
            if f.startswith(base1_genu + str(counter)):
                regexp = r'^SIGN_GEN_USER(\d+)_USER(\d+)_(\d+)'
                x=(re.search(regexp,f))
                if x!=None and int(x.group(3)) <= 15:
                    genuinefiles_session1_tmp.append((f,int(x.group(3))))
                    
                genuinefiles = np.append(genuinefiles,f)
                genuinefiles = list(genuinefiles)
    genuinefiles_session1_tmp.sort(key=lambda x:x[1])
    for x in genuinefiles_session1_tmp:
        genuinefiles_session1.append(x[0])
    print(genuinefiles_session1)
    
    
    #get forgery signature    
    for root, dirs, files in os.walk(base_path_forg + '/USER' + str(counter)):
        for f in files:
            if f.startswith(base1_forg + str(counter)):
                forgeryfiles = np.append(forgeryfiles,f)
                forgeryfiles = list(forgeryfiles)
    if len(genuinefiles) == 0:
        counter += 1
        continue
            
    i = 0
    genu_train_dfs = [] # genuine data
    genu_train_dists = [] # distances between genuine signature
    genu_train_times = [] # times of genuine signature
    genu_train_files = []
    dfs_max_length = 0 # max length(number of points) in trainning dataset

    
    dist_flag = 0 # 0 indicates that it needs to be recalculated
    cal_count = 0
    min_coef_genu_train_dfs = [] # min coef genuine data
    min_coef_genu_train_dists = [] # min coef distances between genuine signature
    min_coef_genu_train_times = [] # min coef times of genuine signature
    min_coef_genu_train_files = []
    min_coef = 1.0 # min coef
    
    sample_choose_start_number = 0
    while  len(genu_train_files)==0 or dist_flag == 0:
        genu_train_files = random.sample(genuinefiles_session1, TRAINING_SET_SIZE)
#         genu_train_files = genuinefiles_session1[sample_choose_start_number:(sample_choose_start_number+TRAINING_SET_SIZE)]
        sample_choose_start_number += 1
        genu_train_dfs = [] # genuine data
        genu_train_dists = [] # distances between genuine signature
        genu_train_times = [] # times of genuine signature
        
        dfs_max_length = cal_dfs_max_length(base_path_genu + '/USER' + str(counter), genu_train_files)
        for f in genu_train_files:
            temp = str(base_path_genu+ '/USER' + str(counter) + '/' +f)
            df = pd.read_csv(temp,delimiter=' ', names=FILE_FEATURE_NAMES, header=None, skiprows=1)
#             df = pd.read_csv(temp,delimiter=',', header=0, names=['X', 'Y','TStamp','Pres'], usecols=[0,1,2,3])
            df['EndPts'] = 0
#             df = preprocess(df, dfs_max_length)
            genu_train_times.append(df['TStamp2'][len(df)-1])                       
            genu_train_dfs.append(df)

        #calculate the threshold distance from training set
        for i in range(0, len(genu_train_dfs)-1):
            data1 = genu_train_dfs[i]
            for j in range(i+1, len(genu_train_dfs)):
                data2 = genu_train_dfs[j]
                #set ts_a
                ts_a = get_ts(data1)

                #set ts_b
                ts_b =  get_ts(data2)
#                 print(len(ts_a))
                distance, path = fastdtw(ts_a, ts_b, radius=FEATRUE_NUM, dist=euclidean)
                if DEBUG_MODE:
                    print("genuine signature distance: ", distance)
                genu_train_dists.append(distance)
        
        cal_count += 1
        
        # 判断是否训练集的dtw距离都小于规定值，如果不小于重新算
        # Determine whether the dtw distance of the training set is less than the specified value, perform the recalculation if not less than it
        dist_flag = 1
        print('Coefficient of Variation:',np.std(genu_train_dists)/np.mean(genu_train_dists))
        coef_var = np.std(genu_train_dists)/np.mean(genu_train_dists)
        
        # 计算并保存一个最小的coef值，如果超过最大的cal_count值，则直接把这个值所表示的训练集当做真正的训练集
        # Calculate and save a minimum coef value. If it exceeds the maximum cal_count value, 
        # the training set of this coef value is directly regarded as the real training set
        if coef_var < min_coef:
            min_coef_genu_train_dfs = genu_train_dfs
            min_coef_genu_train_dists = genu_train_dists
            min_coef_genu_train_times = genu_train_times
            min_coef_genu_train_files = genu_train_files
            min_coef = coef_var
            
        
        # 如果离散系数大于0.13 或者 (最大值-最小值)/平均值 > 0.2 重新选训练集
        # If the coefficient of variation is greater than 0.13 or (maximum-minimum)/average value> 0.2, reselect the training set
        if coef_var > 0.13 :
            dist_flag = 0
            print ("higher coefficient of variation")
        elif (max(genu_train_dists) - min(genu_train_dists))/((max(genu_train_dists) + min(genu_train_dists))/2)>0.28:
            dist_flag = 0
            print("higher extreme value coefficient",max(genu_train_dists),min(genu_train_dists),
                  (max(genu_train_dists) - min(genu_train_dists))/((max(genu_train_dists) + min(genu_train_dists))/2)) 
        # 超过了max_cal_count的话，就直接选最小的coef,不再继续算了    
        # If it has tried more than the max_cal_count, just choose the smallest coef instead of calculating further
        if dist_flag == 0 and cal_count >= 5:         
            genu_train_dfs = min_coef_genu_train_dfs
            genu_train_dists  = min_coef_genu_train_dists
            genu_train_times  = min_coef_genu_train_times
            genu_train_files  = min_coef_genu_train_files
            dist_flag = 1

    
                       
    min_train_dist = min(genu_train_dists)
    mean_train_dist = np.mean(genu_train_dists)
#     threshold = min_train_dist * 1.2
    print(np.std(genu_train_dists))
    
    buffer = 0
#     if np.std(genu_train_dists) * 2.3 < 0.22 * mean_train_dist:
#         buffer = 0.22 * mean_train_dist
#     else:    
#         buffer = np.std(genu_train_dists) * 2.3
    if np.std(genu_train_dists) * 3.2 < 0.3 * mean_train_dist:
        buffer = 0.3 * mean_train_dist
        print("mean is chosen as buffer")
    else:    
        buffer = np.std(genu_train_dists) * 3.2
        print(" Standard deviation is chosen as buffer")
            
    threshold = mean_train_dist + buffer  
    threshold_time = max(genu_train_times)*2 # maximum time of genuine siganature in training set
    
    test_dfs = []
    total_num = len(genuinefiles) + len(forgeryfiles) 
    TP = 0.0
    FP = 0.0 
    FN = 0.0
    TN = 0.0
    
    for f in genuinefiles:
        if f in genu_train_files: # ignore samples in trainning set
            total_num -= 1
            continue
        print(f)    
        temp = str(base_path_genu+ '/USER' + str(counter) + '/' +f)
#         df = pd.read_csv(temp,delimiter=',', header=0, names=['X', 'Y','TStamp','Pres'], usecols=[0,1,2,3])
        df = pd.read_csv(temp,delimiter=' ', names=FILE_FEATURE_NAMES, header=None, skiprows=1)    
        df['EndPts'] = 0
        if (df['TStamp'].max() - df['TStamp'].min()) > threshold_time:
            FN += 1
            continue
#         df = preprocess(df,dfs_max_length)
        test_dfs.append(df) 
     
    test_dfs_geni_num = len(test_dfs)
    print('test_dfs_geni_num:' + str(test_dfs_geni_num) + ',:' + str(len(genuinefiles) - TRAINING_SET_SIZE))
    for f in forgeryfiles:
        print(f)
        temp = str(base_path_forg+ '/USER' + str(counter) + '/' +f)
#         df = pd.read_csv(temp,delimiter=',', header=0, names=['X', 'Y','TStamp','Pres'], usecols=[0,1,2,3])
        df = pd.read_csv(temp,delimiter=' ', names=FILE_FEATURE_NAMES, header=None, skiprows=1)
        df['EndPts'] = 0
        if (df['TStamp'].max() - df['TStamp'].min()) > threshold_time:
            TN += 1
            continue
#         df = preprocess(df,dfs_max_length)
        test_dfs.append(df)
    
    
    #calculate the min distance from each test to training set, if d <= threshold, we say it is genuine, otherwise forgery 
    for i in range(0, len(test_dfs)):
        data1 = test_dfs[i]
        test_dists = []
        for j in range(0, len(genu_train_dfs)):
            data2 = genu_train_dfs[j]
            #set ts_a
            ts_a =  get_ts(data1)
            #set ts_b
            ts_b =  get_ts(data2)
            distance, path = fastdtw(ts_a, ts_b, radius=FEATRUE_NUM,dist=euclidean)
            test_dists.append(distance)
            
        min_test_dist = min(test_dists)
        max_test_dist = max(test_dists)
        mean_test_dist = np.mean(test_dists)
        test_dist_chosen = mean_test_dist # choose the mean of test distances
        if min_test_dist == 0:
            total_num -= 1
            print(total_num)
            continue
            
        if DEBUG_MODE:    
            print("test signature min distance: ", min_test_dist," mean distance: ", mean_test_dist, " threshold: ", threshold)
        if test_dist_chosen > threshold  and i<test_dfs_geni_num:
            FN += 1.0
        elif  test_dist_chosen > threshold and i>=test_dfs_geni_num:
            TN += 1.0
        elif  test_dist_chosen <= threshold and i<test_dfs_geni_num:
            TP += 1.0
        elif  test_dist_chosen <= threshold and i>=test_dfs_geni_num:
            FP += 1.0        
            
            
    genu_test_num = len(genuinefiles) - TRAINING_SET_SIZE
    forg_test_num = len(forgeryfiles)
#     print('genu_test_num:' + str(genu_test_num) + ',forg_test_num:' + str(forg_test_num))
    
    accuracy = (TP + TN)/total_num * 100
    FRR = FN/genu_test_num *100 #
    FAR = FP/forg_test_num *100 #
    
    TOTAL_NUM += total_num
    TOTAL_GENU += genu_test_num
    TOTAL_FORG += forg_test_num
    TOTAL_FN += FN
    TOTAL_FP += FP
    TOTAL_FRR = TOTAL_FN/TOTAL_GENU * 100
    TOTAL_FAR = TOTAL_FP/TOTAL_FORG *100
    
    TOTAL_ACCU = (TOTAL_NUM - TOTAL_FN - TOTAL_FP) / TOTAL_NUM * 100
    print("test num: " + str(total_num) + ", accuracy: " + str(accuracy) + "%")
    print("FRR: " + str(FRR) + "%, FAR: " + str(FAR)+ "%")
    print("TOTAL_FRR: " + str(TOTAL_FRR) + "%, TOTAL_FAR: " + str(TOTAL_FAR)+ "%, TOTAL_TEST_SIGN:" + 
          str(TOTAL_NUM/(genu_test_num + forg_test_num)) + "TOTAL_ACCU: " + str(TOTAL_ACCU) + "%")
    print("\n") 
    
    counter = counter + 1
# Out:
# ['SIGN_GEN_USER1_USER1_1.csv', 'SIGN_GEN_USER1_USER1_2.csv', 'SIGN_GEN_USER1_USER1_3.csv', 'SIGN_GEN_USER1_USER1_4.csv', 'SIGN_GEN_USER1_USER1_5.csv', 'SIGN_GEN_USER1_USER1_6.csv', 'SIGN_GEN_USER1_USER1_7.csv', 'SIGN_GEN_USER1_USER1_8.csv', 'SIGN_GEN_USER1_USER1_9.csv', 'SIGN_GEN_USER1_USER1_10.csv', 'SIGN_GEN_USER1_USER1_11.csv', 'SIGN_GEN_USER1_USER1_12.csv', 'SIGN_GEN_USER1_USER1_13.csv', 'SIGN_GEN_USER1_USER1_14.csv', 'SIGN_GEN_USER1_USER1_15.csv']
# 177
# genuine signature distance:  195.4757931215326
# genuine signature distance:  214.64635879438316
# genuine signature distance:  219.41953498881531
# 离散系数: 0.04930865201939146
# 10.347283990428691
# buffer选择的均值
# SIGN_GEN_USER1_USER1_10.csv
# SIGN_GEN_USER1_USER1_13.csv
# SIGN_GEN_USER1_USER1_14.csv
# SIGN_GEN_USER1_USER1_15.csv
# SIGN_GEN_USER1_USER1_16.csv
# SIGN_GEN_USER1_USER1_17.csv
# SIGN_GEN_USER1_USER1_18.csv
# SIGN_GEN_USER1_USER1_19.csv
# SIGN_GEN_USER1_USER1_2.csv
# SIGN_GEN_USER1_USER1_20.csv
# SIGN_GEN_USER1_USER1_21.csv
# SIGN_GEN_USER1_USER1_22.csv
# SIGN_GEN_USER1_USER1_23.csv
# SIGN_GEN_USER1_USER1_24.csv
# SIGN_GEN_USER1_USER1_25.csv
# SIGN_GEN_USER1_USER1_26.csv
# SIGN_GEN_USER1_USER1_27.csv
# SIGN_GEN_USER1_USER1_28.csv
# SIGN_GEN_USER1_USER1_29.csv
# SIGN_GEN_USER1_USER1_3.csv
# SIGN_GEN_USER1_USER1_30.csv
# SIGN_GEN_USER1_USER1_31.csv
# SIGN_GEN_USER1_USER1_32.csv
# SIGN_GEN_USER1_USER1_33.csv
# SIGN_GEN_USER1_USER1_34.csv
# SIGN_GEN_USER1_USER1_35.csv
# SIGN_GEN_USER1_USER1_36.csv
# SIGN_GEN_USER1_USER1_37.csv
# SIGN_GEN_USER1_USER1_38.csv
# SIGN_GEN_USER1_USER1_39.csv
# SIGN_GEN_USER1_USER1_4.csv
# SIGN_GEN_USER1_USER1_40.csv
# SIGN_GEN_USER1_USER1_41.csv
# SIGN_GEN_USER1_USER1_42.csv
# SIGN_GEN_USER1_USER1_43.csv
# SIGN_GEN_USER1_USER1_44.csv
# SIGN_GEN_USER1_USER1_45.csv
# SIGN_GEN_USER1_USER1_5.csv
# SIGN_GEN_USER1_USER1_6.csv
# SIGN_GEN_USER1_USER1_7.csv
# SIGN_GEN_USER1_USER1_8.csv
# SIGN_GEN_USER1_USER1_9.csv
# test_dfs_geni_num:42,:42
# SIGN_FOR_USER1_USER2_1.csv
# SIGN_FOR_USER1_USER2_2.csv
# SIGN_FOR_USER1_USER2_3.csv
# SIGN_FOR_USER1_USER2_4.csv
# SIGN_FOR_USER1_USER2_5.csv
# SIGN_FOR_USER1_USER3_10.csv
# SIGN_FOR_USER1_USER3_6.csv
# SIGN_FOR_USER1_USER3_7.csv
# SIGN_FOR_USER1_USER3_8.csv
# SIGN_FOR_USER1_USER3_9.csv
# SIGN_FOR_USER1_USER4_11.csv
# SIGN_FOR_USER1_USER4_12.csv
# SIGN_FOR_USER1_USER4_13.csv
# SIGN_FOR_USER1_USER4_14.csv
# SIGN_FOR_USER1_USER4_15.csv
# SIGN_FOR_USER1_USER4_16.csv
# SIGN_FOR_USER1_USER4_17.csv
# SIGN_FOR_USER1_USER4_18.csv
# SIGN_FOR_USER1_USER4_19.csv
# SIGN_FOR_USER1_USER4_20.csv
# test signature min distance:  165.14522693002743  mean distance:  202.56060555954093  threshold:  272.8013976587168
# test signature min distance:  158.69514362233727  mean distance:  200.77691963708253  threshold:  272.8013976587168
# test signature min distance:  190.65275428424297  mean distance:  202.33531568884072  threshold:  272.8013976587168
# test signature min distance:  201.9022019789555  mean distance:  227.64625020135054  threshold:  272.8013976587168
# test signature min distance:  206.15489468283874  mean distance:  221.61186889469937  threshold:  272.8013976587168
# test signature min distance:  199.95912936999522  mean distance:  212.13616923130635  threshold:  272.8013976587168
# test signature min distance:  203.67633980013903  mean distance:  244.1130576986134  threshold:  272.8013976587168
# test signature min distance:  207.09377338048222  mean distance:  228.18168985472548  threshold:  272.8013976587168
# test signature min distance:  189.47181665618473  mean distance:  205.4429872251881  threshold:  272.8013976587168
# test signature min distance:  220.9679235970036  mean distance:  239.20896326506536  threshold:  272.8013976587168
# test signature min distance:  177.22912554523214  mean distance:  216.12695091558032  threshold:  272.8013976587168
# test signature min distance:  162.19398109001474  mean distance:  184.73349884477443  threshold:  272.8013976587168
# test signature min distance:  200.1801003775329  mean distance:  238.19237194424446  threshold:  272.8013976587168
# test signature min distance:  245.96712822925934  mean distance:  267.1127859921587  threshold:  272.8013976587168
# test signature min distance:  218.46474379151834  mean distance:  242.64922317754517  threshold:  272.8013976587168
# test signature min distance:  248.58695657365837  mean distance:  275.0595237754621  threshold:  272.8013976587168
# test signature min distance:  181.61114768939456  mean distance:  211.600078206444  threshold:  272.8013976587168
# test signature min distance:  186.222517341765  mean distance:  219.70746252723612  threshold:  272.8013976587168
# test signature min distance:  227.65129557092098  mean distance:  261.94446579766753  threshold:  272.8013976587168
# test signature min distance:  238.6974477739248  mean distance:  245.56630200067366  threshold:  272.8013976587168
# test signature min distance:  228.27749965690657  mean distance:  260.2050260314458  threshold:  272.8013976587168
# test signature min distance:  205.6748373688529  mean distance:  231.87276985832762  threshold:  272.8013976587168
# test signature min distance:  271.1973729690042  mean distance:  304.11009771031917  threshold:  272.8013976587168
# test signature min distance:  202.2737580585227  mean distance:  246.3966139204689  threshold:  272.8013976587168
# test signature min distance:  181.77196010165983  mean distance:  195.54721999915873  threshold:  272.8013976587168
# test signature min distance:  182.1653443147249  mean distance:  217.27909570146826  threshold:  272.8013976587168
# test signature min distance:  181.93490256024262  mean distance:  227.4070180862378  threshold:  272.8013976587168
# test signature min distance:  179.38708414998305  mean distance:  211.26855508918632  threshold:  272.8013976587168
# test signature min distance:  202.11260523533073  mean distance:  243.6260909684613  threshold:  272.8013976587168
# test signature min distance:  195.24596876326814  mean distance:  226.64156993445417  threshold:  272.8013976587168
# test signature min distance:  184.8399829802591  mean distance:  220.1959690666473  threshold:  272.8013976587168
# test signature min distance:  236.63363979569195  mean distance:  238.98784923161233  threshold:  272.8013976587168
# test signature min distance:  169.03819410996593  mean distance:  197.7293851227946  threshold:  272.8013976587168
# test signature min distance:  203.47735584947912  mean distance:  235.35553885232866  threshold:  272.8013976587168
# test signature min distance:  172.5659597470244  mean distance:  206.82372303403966  threshold:  272.8013976587168
# test signature min distance:  188.5197576975873  mean distance:  227.63176266790632  threshold:  272.8013976587168
# test signature min distance:  180.70426164643135  mean distance:  221.69475415688876  threshold:  272.8013976587168
# test signature min distance:  185.4749661949217  mean distance:  222.43396484756136  threshold:  272.8013976587168
# test signature min distance:  181.07197131438747  mean distance:  196.029002429276  threshold:  272.8013976587168
# test signature min distance:  193.71630315119597  mean distance:  213.60444376044578  threshold:  272.8013976587168
# test signature min distance:  210.71716549784708  mean distance:  227.40869998840859  threshold:  272.8013976587168
# test signature min distance:  154.0037599300974  mean distance:  199.20843798716695  threshold:  272.8013976587168
# test signature min distance:  275.9234646119418  mean distance:  283.8528092797446  threshold:  272.8013976587168
# test signature min distance:  269.34347103002693  mean distance:  279.53223830626797  threshold:  272.8013976587168
# test signature min distance:  282.72508458578466  mean distance:  302.3407710801254  threshold:  272.8013976587168
# test signature min distance:  294.1838520976442  mean distance:  298.50850448235934  threshold:  272.8013976587168
# test signature min distance:  314.3236937403956  mean distance:  321.8640796916407  threshold:  272.8013976587168
# test signature min distance:  281.5637261625206  mean distance:  299.8174595443182  threshold:  272.8013976587168
# test signature min distance:  263.8242819462588  mean distance:  276.08268015852724  threshold:  272.8013976587168
# test num: 62, accuracy: 96.7741935483871%
# FRR: 4.761904761904762%, FAR: 0.0%
# TOTAL_FRR: 4.761904761904762%, TOTAL_FAR: 0.0%, TOTAL_TEST_SIGN:1.0TOTAL_ACCU: 96.7741935483871%
#
#
# ['SIGN_GEN_USER2_USER2_1.csv', 'SIGN_GEN_USER2_USER2_2.csv', 'SIGN_GEN_USER2_USER2_3.csv', 'SIGN_GEN_USER2_USER2_4.csv', 'SIGN_GEN_USER2_USER2_5.csv', 'SIGN_GEN_USER2_USER2_6.csv', 'SIGN_GEN_USER2_USER2_7.csv', 'SIGN_GEN_USER2_USER2_8.csv', 'SIGN_GEN_USER2_USER2_9.csv', 'SIGN_GEN_USER2_USER2_10.csv', 'SIGN_GEN_USER2_USER2_11.csv', 'SIGN_GEN_USER2_USER2_12.csv', 'SIGN_GEN_USER2_USER2_13.csv', 'SIGN_GEN_USER2_USER2_14.csv', 'SIGN_GEN_USER2_USER2_15.csv']
# 164
# genuine signature distance:  168.71037923468768
# genuine signature distance:  172.51426138229596
# genuine signature distance:  193.66991917584852
# 离散系数: 0.06158127714851276
# 10.979830043944707
# buffer选择的均值
# SIGN_GEN_USER2_USER2_1.csv
# SIGN_GEN_USER2_USER2_10.csv
# SIGN_GEN_USER2_USER2_11.csv
# SIGN_GEN_USER2_USER2_15.csv
# SIGN_GEN_USER2_USER2_16.csv
# SIGN_GEN_USER2_USER2_17.csv
# SIGN_GEN_USER2_USER2_18.csv
# SIGN_GEN_USER2_USER2_19.csv
# SIGN_GEN_USER2_USER2_2.csv
# SIGN_GEN_USER2_USER2_20.csv
# SIGN_GEN_USER2_USER2_21.csv
# SIGN_GEN_USER2_USER2_22.csv
# SIGN_GEN_USER2_USER2_23.csv
# SIGN_GEN_USER2_USER2_24.csv
# SIGN_GEN_USER2_USER2_25.csv
# SIGN_GEN_USER2_USER2_26.csv
# SIGN_GEN_USER2_USER2_27.csv
# SIGN_GEN_USER2_USER2_28.csv
# SIGN_GEN_USER2_USER2_29.csv
# SIGN_GEN_USER2_USER2_3.csv
# SIGN_GEN_USER2_USER2_30.csv
# SIGN_GEN_USER2_USER2_31.csv
# SIGN_GEN_USER2_USER2_32.csv
# SIGN_GEN_USER2_USER2_33.csv
# SIGN_GEN_USER2_USER2_34.csv
# SIGN_GEN_USER2_USER2_35.csv
# SIGN_GEN_USER2_USER2_36.csv
# SIGN_GEN_USER2_USER2_37.csv
# SIGN_GEN_USER2_USER2_38.csv
# SIGN_GEN_USER2_USER2_39.csv
# SIGN_GEN_USER2_USER2_4.csv
# SIGN_GEN_USER2_USER2_40.csv
# SIGN_GEN_USER2_USER2_41.csv
# SIGN_GEN_USER2_USER2_42.csv
# SIGN_GEN_USER2_USER2_43.csv
# SIGN_GEN_USER2_USER2_44.csv
# SIGN_GEN_USER2_USER2_45.csv
# SIGN_GEN_USER2_USER2_5.csv
# SIGN_GEN_USER2_USER2_6.csv
# SIGN_GEN_USER2_USER2_7.csv
# SIGN_GEN_USER2_USER2_8.csv
# SIGN_GEN_USER2_USER2_9.csv
# test_dfs_geni_num:42,:42
# SIGN_FOR_USER2_USER3_1.csv
# SIGN_FOR_USER2_USER3_2.csv
# SIGN_FOR_USER2_USER3_3.csv
# SIGN_FOR_USER2_USER3_4.csv
# SIGN_FOR_USER2_USER3_5.csv
# SIGN_FOR_USER2_USER4_10.csv
# SIGN_FOR_USER2_USER4_6.csv
# SIGN_FOR_USER2_USER4_7.csv
# SIGN_FOR_USER2_USER4_8.csv
# SIGN_FOR_USER2_USER4_9.csv
# SIGN_FOR_USER2_USER5_11.csv
# SIGN_FOR_USER2_USER5_12.csv
# SIGN_FOR_USER2_USER5_13.csv
# SIGN_FOR_USER2_USER5_14.csv
# SIGN_FOR_USER2_USER5_15.csv
# SIGN_FOR_USER2_USER5_16.csv
# SIGN_FOR_USER2_USER5_17.csv
# SIGN_FOR_USER2_USER5_18.csv
# SIGN_FOR_USER2_USER5_19.csv
# SIGN_FOR_USER2_USER5_20.csv
# test signature min distance:  196.6119903320352  mean distance:  219.31772697321387  threshold:  231.7876425768939
# test signature min distance:  175.42537661548738  mean distance:  178.82983772102043  threshold:  231.7876425768939
# test signature min distance:  162.14060404561542  mean distance:  169.1533645036493  threshold:  231.7876425768939
# test signature min distance:  153.32071232608072  mean distance:  163.53835385102747  threshold:  231.7876425768939
# test signature min distance:  204.42697474735024  mean distance:  211.53187076583137  threshold:  231.7876425768939
# test signature min distance:  192.97638625816435  mean distance:  198.02284592521428  threshold:  231.7876425768939
# test signature min distance:  175.01848502622738  mean distance:  185.3875216895028  threshold:  231.7876425768939
# test signature min distance:  214.83769608814728  mean distance:  215.60653830737445  threshold:  231.7876425768939
# test signature min distance:  187.5816085222988  mean distance:  195.53984294315455  threshold:  231.7876425768939
# test signature min distance:  191.8536926438477  mean distance:  201.71127603537548  threshold:  231.7876425768939
# test signature min distance:  186.48461321484663  mean distance:  193.55367790368393  threshold:  231.7876425768939
# test signature min distance:  184.23722529118027  mean distance:  189.01591272433157  threshold:  231.7876425768939
# test signature min distance:  168.18650737456937  mean distance:  174.807593537246  threshold:  231.7876425768939
# test signature min distance:  176.1026977935867  mean distance:  182.31994000663556  threshold:  231.7876425768939
# test signature min distance:  161.90790224639096  mean distance:  182.1303482854844  threshold:  231.7876425768939
# test signature min distance:  175.3847592409388  mean distance:  182.63860671017892  threshold:  231.7876425768939
# test signature min distance:  193.3405364231483  mean distance:  198.52341054810393  threshold:  231.7876425768939
# test signature min distance:  184.13298530541118  mean distance:  198.48925279483103  threshold:  231.7876425768939
# test signature min distance:  177.75769832573968  mean distance:  187.82982634424366  threshold:  231.7876425768939
# test signature min distance:  221.35345829672437  mean distance:  228.51783179223185  threshold:  231.7876425768939
# test signature min distance:  175.1166990282464  mean distance:  186.72107873836615  threshold:  231.7876425768939
# test signature min distance:  224.54835846924527  mean distance:  234.0837378918768  threshold:  231.7876425768939
# test signature min distance:  214.99869819960028  mean distance:  226.6775950907654  threshold:  231.7876425768939
# test signature min distance:  224.2405371688008  mean distance:  232.37277489515807  threshold:  231.7876425768939
# test signature min distance:  213.79289589334863  mean distance:  221.57295381730557  threshold:  231.7876425768939
# test signature min distance:  203.5327107705934  mean distance:  213.2305342544635  threshold:  231.7876425768939
# test signature min distance:  210.03489141093178  mean distance:  217.6182473742571  threshold:  231.7876425768939
# test signature min distance:  218.42937680223943  mean distance:  223.51492636121577  threshold:  231.7876425768939
# test signature min distance:  208.38771711264144  mean distance:  218.6005972605707  threshold:  231.7876425768939
# test signature min distance:  189.99976735261498  mean distance:  210.62277897711098  threshold:  231.7876425768939
# test signature min distance:  211.50339731618016  mean distance:  215.87820093212954  threshold:  231.7876425768939
# test signature min distance:  187.54302738506863  mean distance:  202.74094129105035  threshold:  231.7876425768939
# test signature min distance:  198.5096930208143  mean distance:  208.2144812303843  threshold:  231.7876425768939
# test signature min distance:  209.9995251018915  mean distance:  214.3369006319649  threshold:  231.7876425768939
# test signature min distance:  197.5844988986497  mean distance:  206.75240386164174  threshold:  231.7876425768939
# test signature min distance:  209.45502247314616  mean distance:  221.26579304646393  threshold:  231.7876425768939
# test signature min distance:  244.70148855112714  mean distance:  252.8349182059037  threshold:  231.7876425768939
# test signature min distance:  204.27962884149824  mean distance:  208.64783552467233  threshold:  231.7876425768939
# test signature min distance:  206.15995638379562  mean distance:  220.95114172949502  threshold:  231.7876425768939
# test signature min distance:  225.03641898563015  mean distance:  231.4392140371646  threshold:  231.7876425768939
# test signature min distance:  192.87400597365314  mean distance:  198.89021758686246  threshold:  231.7876425768939
# test signature min distance:  185.5068635766741  mean distance:  189.3895171261306  threshold:  231.7876425768939
# test signature min distance:  318.41085026437304  mean distance:  322.6224557829937  threshold:  231.7876425768939
# test signature min distance:  310.53627996433477  mean distance:  323.56296922596465  threshold:  231.7876425768939
# test signature min distance:  302.8451711568122  mean distance:  308.67869987019964  threshold:  231.7876425768939
# test num: 62, accuracy: 95.16129032258065%
# FRR: 7.142857142857142%, FAR: 0.0%
# TOTAL_FRR: 5.952380952380952%, TOTAL_FAR: 0.0%, TOTAL_TEST_SIGN:2.0TOTAL_ACCU: 95.96774193548387%
#
#
# ['SIGN_GEN_USER3_USER3_1.csv', 'SIGN_GEN_USER3_USER3_2.csv', 'SIGN_GEN_USER3_USER3_3.csv', 'SIGN_GEN_USER3_USER3_4.csv', 'SIGN_GEN_USER3_USER3_5.csv', 'SIGN_GEN_USER3_USER3_6.csv', 'SIGN_GEN_USER3_USER3_7.csv', 'SIGN_GEN_USER3_USER3_8.csv', 'SIGN_GEN_USER3_USER3_9.csv', 'SIGN_GEN_USER3_USER3_10.csv', 'SIGN_GEN_USER3_USER3_11.csv', 'SIGN_GEN_USER3_USER3_12.csv', 'SIGN_GEN_USER3_USER3_13.csv', 'SIGN_GEN_USER3_USER3_14.csv', 'SIGN_GEN_USER3_USER3_15.csv']
# 156
# genuine signature distance:  212.2381552535753
# genuine signature distance:  174.82997999404628
# genuine signature distance:  229.74909844364032
# 离散系数: 0.11140681215263763
# 22.905880562117336
# buffer选择的标准差
# SIGN_GEN_USER3_USER3_1.csv
# SIGN_GEN_USER3_USER3_10.csv
# SIGN_GEN_USER3_USER3_11.csv
# SIGN_GEN_USER3_USER3_13.csv
# SIGN_GEN_USER3_USER3_15.csv
# SIGN_GEN_USER3_USER3_16.csv
# SIGN_GEN_USER3_USER3_17.csv
# SIGN_GEN_USER3_USER3_18.csv
# SIGN_GEN_USER3_USER3_19.csv
# SIGN_GEN_USER3_USER3_20.csv
# SIGN_GEN_USER3_USER3_21.csv
# SIGN_GEN_USER3_USER3_22.csv
# SIGN_GEN_USER3_USER3_23.csv
# SIGN_GEN_USER3_USER3_24.csv
# SIGN_GEN_USER3_USER3_25.csv
# SIGN_GEN_USER3_USER3_26.csv
# SIGN_GEN_USER3_USER3_27.csv
# SIGN_GEN_USER3_USER3_28.csv
# SIGN_GEN_USER3_USER3_29.csv
# SIGN_GEN_USER3_USER3_3.csv
# SIGN_GEN_USER3_USER3_30.csv
# SIGN_GEN_USER3_USER3_31.csv
# SIGN_GEN_USER3_USER3_32.csv
# SIGN_GEN_USER3_USER3_33.csv
# SIGN_GEN_USER3_USER3_34.csv
# SIGN_GEN_USER3_USER3_35.csv
# SIGN_GEN_USER3_USER3_36.csv
# SIGN_GEN_USER3_USER3_37.csv
# SIGN_GEN_USER3_USER3_38.csv
# SIGN_GEN_USER3_USER3_39.csv
# SIGN_GEN_USER3_USER3_4.csv
# SIGN_GEN_USER3_USER3_40.csv
# SIGN_GEN_USER3_USER3_41.csv
# SIGN_GEN_USER3_USER3_42.csv
# SIGN_GEN_USER3_USER3_43.csv
# SIGN_GEN_USER3_USER3_44.csv
# SIGN_GEN_USER3_USER3_45.csv
# SIGN_GEN_USER3_USER3_5.csv
# SIGN_GEN_USER3_USER3_6.csv
# SIGN_GEN_USER3_USER3_7.csv
# SIGN_GEN_USER3_USER3_8.csv
# SIGN_GEN_USER3_USER3_9.csv
# test_dfs_geni_num:42,:42
# SIGN_FOR_USER3_USER4_1.csv
# SIGN_FOR_USER3_USER4_2.csv
# SIGN_FOR_USER3_USER4_3.csv
# SIGN_FOR_USER3_USER4_4.csv
# SIGN_FOR_USER3_USER4_5.csv
# SIGN_FOR_USER3_USER5_10.csv
# SIGN_FOR_USER3_USER5_6.csv
# SIGN_FOR_USER3_USER5_7.csv
# SIGN_FOR_USER3_USER5_8.csv
# SIGN_FOR_USER3_USER5_9.csv
# SIGN_FOR_USER3_USER6_11.csv
# SIGN_FOR_USER3_USER6_12.csv
# SIGN_FOR_USER3_USER6_13.csv
# SIGN_FOR_USER3_USER6_14.csv
# SIGN_FOR_USER3_USER6_15.csv
# SIGN_FOR_USER3_USER7_16.csv
# SIGN_FOR_USER3_USER7_17.csv
# SIGN_FOR_USER3_USER7_18.csv
# SIGN_FOR_USER3_USER7_19.csv
# SIGN_FOR_USER3_USER7_20.csv
# test signature min distance:  184.60780053632743  mean distance:  191.8320415398099  threshold:  278.9045623625294
# test signature min distance:  161.09762525850778  mean distance:  181.41651058692946  threshold:  278.9045623625294
# test signature min distance:  156.34947271937614  mean distance:  175.97740564279647  threshold:  278.9045623625294
# test signature min distance:  150.53182705756103  mean distance:  175.4826014396015  threshold:  278.9045623625294
# test signature min distance:  172.95424546020297  mean distance:  179.5957255806646  threshold:  278.9045623625294
# test signature min distance:  186.07232540825194  mean distance:  198.2980402545202  threshold:  278.9045623625294
# test signature min distance:  158.2016586976023  mean distance:  184.05543568823512  threshold:  278.9045623625294
# test signature min distance:  168.84268118625042  mean distance:  184.49869901710872  threshold:  278.9045623625294
# test signature min distance:  167.07104319041235  mean distance:  177.59546128773286  threshold:  278.9045623625294
# test signature min distance:  163.69263877489817  mean distance:  184.83880037180006  threshold:  278.9045623625294
# test signature min distance:  156.39354081537297  mean distance:  189.51537277375374  threshold:  278.9045623625294
# test signature min distance:  157.75463270696892  mean distance:  177.9376442718128  threshold:  278.9045623625294
# test signature min distance:  156.92291598552794  mean distance:  177.53724433503348  threshold:  278.9045623625294
# test signature min distance:  161.15353263800557  mean distance:  179.9404518733032  threshold:  278.9045623625294
# test signature min distance:  146.2756471513362  mean distance:  178.92873252831797  threshold:  278.9045623625294
# test signature min distance:  160.27050595152784  mean distance:  181.3677675278859  threshold:  278.9045623625294
# test signature min distance:  164.31824641786574  mean distance:  182.84898019654597  threshold:  278.9045623625294
# test signature min distance:  171.7520946728206  mean distance:  182.69436760008838  threshold:  278.9045623625294
# test signature min distance:  173.70544846842088  mean distance:  189.75092992875457  threshold:  278.9045623625294
# test signature min distance:  181.43336063803892  mean distance:  196.32217362079155  threshold:  278.9045623625294
# test signature min distance:  148.19956264861048  mean distance:  180.91367525094662  threshold:  278.9045623625294
# test signature min distance:  159.87470769269703  mean distance:  180.0697953914088  threshold:  278.9045623625294
# test signature min distance:  163.1339118231853  mean distance:  174.22390278643113  threshold:  278.9045623625294
# test signature min distance:  164.48877709798165  mean distance:  192.36371005994638  threshold:  278.9045623625294
# test signature min distance:  166.39730274818928  mean distance:  184.55918674219322  threshold:  278.9045623625294
# test signature min distance:  137.84306967181715  mean distance:  173.0428990340695  threshold:  278.9045623625294
# test signature min distance:  165.7723536875414  mean distance:  187.31844841022064  threshold:  278.9045623625294
# test signature min distance:  164.01006602017748  mean distance:  185.23798239005637  threshold:  278.9045623625294
# test signature min distance:  147.51942888369538  mean distance:  171.96809784670532  threshold:  278.9045623625294
# test signature min distance:  149.75010887883565  mean distance:  186.6402592243147  threshold:  278.9045623625294
# test signature min distance:  164.18167542949504  mean distance:  177.5648749452536  threshold:  278.9045623625294
# test signature min distance:  164.4115368524476  mean distance:  182.3324016113311  threshold:  278.9045623625294
# test signature min distance:  178.4346661885951  mean distance:  188.83343322797245  threshold:  278.9045623625294
# test signature min distance:  149.03512913714476  mean distance:  178.00936857882098  threshold:  278.9045623625294
# test signature min distance:  139.37804299203205  mean distance:  172.56945343570933  threshold:  278.9045623625294
# test signature min distance:  169.22721910133225  mean distance:  194.62245997817573  threshold:  278.9045623625294
# test signature min distance:  166.97095898515025  mean distance:  187.7505482731834  threshold:  278.9045623625294
# test signature min distance:  172.65107771026786  mean distance:  176.67531493084937  threshold:  278.9045623625294
# test signature min distance:  172.28757344580794  mean distance:  195.34148091242855  threshold:  278.9045623625294
# test signature min distance:  170.54018767888766  mean distance:  186.77993840280564  threshold:  278.9045623625294
# test signature min distance:  177.62381131110766  mean distance:  181.55607375984036  threshold:  278.9045623625294
# test signature min distance:  160.44711328531068  mean distance:  174.64400427486575  threshold:  278.9045623625294
# test signature min distance:  232.89630389725284  mean distance:  259.579889428765  threshold:  278.9045623625294
# test signature min distance:  247.15315798678452  mean distance:  273.94310894567957  threshold:  278.9045623625294
# test signature min distance:  213.52651462525867  mean distance:  250.13152612270915  threshold:  278.9045623625294
# test signature min distance:  221.54286646949123  mean distance:  250.898987250161  threshold:  278.9045623625294
# test signature min distance:  336.6963005619984  mean distance:  342.84509885597623  threshold:  278.9045623625294
# test signature min distance:  312.45528067220727  mean distance:  323.72697237108144  threshold:  278.9045623625294
# test signature min distance:  294.49508376461233  mean distance:  312.1897486746689  threshold:  278.9045623625294
# test signature min distance:  327.7587333825801  mean distance:  336.90096439078155  threshold:  278.9045623625294
# test signature min distance:  368.85252514750886  mean distance:  378.43604159105865  threshold:  278.9045623625294
# test num: 62, accuracy: 93.54838709677419%
# FRR: 0.0%, FAR: 20.0%
# TOTAL_FRR: 3.968253968253968%, TOTAL_FAR: 6.666666666666667%, TOTAL_TEST_SIGN:3.0TOTAL_ACCU: 95.16129032258065%
#
#
# ['SIGN_GEN_USER4_USER4_1.csv', 'SIGN_GEN_USER4_USER4_2.csv', 'SIGN_GEN_USER4_USER4_3.csv', 'SIGN_GEN_USER4_USER4_4.csv', 'SIGN_GEN_USER4_USER4_5.csv', 'SIGN_GEN_USER4_USER4_6.csv', 'SIGN_GEN_USER4_USER4_7.csv', 'SIGN_GEN_USER4_USER4_8.csv', 'SIGN_GEN_USER4_USER4_9.csv', 'SIGN_GEN_USER4_USER4_10.csv', 'SIGN_GEN_USER4_USER4_11.csv', 'SIGN_GEN_USER4_USER4_12.csv', 'SIGN_GEN_USER4_USER4_13.csv', 'SIGN_GEN_USER4_USER4_14.csv', 'SIGN_GEN_USER4_USER4_15.csv']
# 493
# genuine signature distance:  556.8797683143798
# genuine signature distance:  560.7646505854178
# genuine signature distance:  572.5093282761187
# 离散系数: 0.011793429772879428
# 6.644236507562725
# buffer选择的均值
# SIGN_GEN_USER4_USER4_1.csv
# SIGN_GEN_USER4_USER4_10.csv
# SIGN_GEN_USER4_USER4_11.csv
# SIGN_GEN_USER4_USER4_12.csv
# SIGN_GEN_USER4_USER4_13.csv
# SIGN_GEN_USER4_USER4_15.csv
# SIGN_GEN_USER4_USER4_16.csv
# SIGN_GEN_USER4_USER4_17.csv
# SIGN_GEN_USER4_USER4_18.csv
# SIGN_GEN_USER4_USER4_19.csv
# SIGN_GEN_USER4_USER4_2.csv
# SIGN_GEN_USER4_USER4_20.csv
# SIGN_GEN_USER4_USER4_21.csv
# SIGN_GEN_USER4_USER4_22.csv
# SIGN_GEN_USER4_USER4_23.csv
# SIGN_GEN_USER4_USER4_24.csv
# SIGN_GEN_USER4_USER4_25.csv
# SIGN_GEN_USER4_USER4_26.csv
# SIGN_GEN_USER4_USER4_27.csv
# SIGN_GEN_USER4_USER4_28.csv
# SIGN_GEN_USER4_USER4_29.csv
# SIGN_GEN_USER4_USER4_3.csv
# SIGN_GEN_USER4_USER4_30.csv
# SIGN_GEN_USER4_USER4_31.csv
# SIGN_GEN_USER4_USER4_32.csv
# SIGN_GEN_USER4_USER4_33.csv
# SIGN_GEN_USER4_USER4_34.csv
# SIGN_GEN_USER4_USER4_35.csv
# SIGN_GEN_USER4_USER4_36.csv
# SIGN_GEN_USER4_USER4_37.csv
# SIGN_GEN_USER4_USER4_38.csv
# SIGN_GEN_USER4_USER4_39.csv
# SIGN_GEN_USER4_USER4_4.csv
# SIGN_GEN_USER4_USER4_40.csv
# SIGN_GEN_USER4_USER4_41.csv
# SIGN_GEN_USER4_USER4_42.csv
# SIGN_GEN_USER4_USER4_43.csv
# SIGN_GEN_USER4_USER4_44.csv
# SIGN_GEN_USER4_USER4_45.csv
# SIGN_GEN_USER4_USER4_5.csv
# SIGN_GEN_USER4_USER4_6.csv
# SIGN_GEN_USER4_USER4_9.csv
# test_dfs_geni_num:38,:42
# SIGN_FOR_USER4_USER5_1.csv
# SIGN_FOR_USER4_USER5_2.csv
# SIGN_FOR_USER4_USER5_3.csv
# SIGN_FOR_USER4_USER5_4.csv
# SIGN_FOR_USER4_USER5_5.csv
# SIGN_FOR_USER4_USER6_10.csv
# SIGN_FOR_USER4_USER6_6.csv
# SIGN_FOR_USER4_USER6_7.csv
# SIGN_FOR_USER4_USER6_8.csv
# SIGN_FOR_USER4_USER6_9.csv
# SIGN_FOR_USER4_USER7_11.csv
# SIGN_FOR_USER4_USER7_12.csv
# SIGN_FOR_USER4_USER7_13.csv
# SIGN_FOR_USER4_USER7_14.csv
# SIGN_FOR_USER4_USER7_15.csv
# SIGN_FOR_USER4_USER7_16.csv
# SIGN_FOR_USER4_USER7_17.csv
# SIGN_FOR_USER4_USER7_18.csv
# SIGN_FOR_USER4_USER7_19.csv
# SIGN_FOR_USER4_USER7_20.csv
# test signature min distance:  532.9182160483787  mean distance:  582.4794003549711  threshold:  732.3999571095636
# test signature min distance:  424.80030511206184  mean distance:  534.6911970525738  threshold:  732.3999571095636
# test signature min distance:  457.1577652535344  mean distance:  551.6183260161597  threshold:  732.3999571095636
# test signature min distance:  423.05120739260815  mean distance:  532.3418073342156  threshold:  732.3999571095636
# test signature min distance:  477.7492156789191  mean distance:  531.2602686806325  threshold:  732.3999571095636
# test signature min distance:  453.406203906023  mean distance:  541.8533897098363  threshold:  732.3999571095636
# test signature min distance:  572.8629297493238  mean distance:  652.0373084073135  threshold:  732.3999571095636
# test signature min distance:  600.1184906266286  mean distance:  702.3647005199482  threshold:  732.3999571095636
# test signature min distance:  548.6281271105273  mean distance:  683.4960737132104  threshold:  732.3999571095636
# test signature min distance:  578.3831965716664  mean distance:  626.2957828448085  threshold:  732.3999571095636
# test signature min distance:  477.0460286290351  mean distance:  579.1730286445288  threshold:  732.3999571095636
# test signature min distance:  534.0135268122455  mean distance:  646.7253447726771  threshold:  732.3999571095636
# test signature min distance:  561.5539235747782  mean distance:  614.934018020791  threshold:  732.3999571095636
# test signature min distance:  601.0069936450382  mean distance:  674.389504402659  threshold:  732.3999571095636
# test signature min distance:  631.5414454568505  mean distance:  741.0273325692388  threshold:  732.3999571095636
# test signature min distance:  617.4515641902685  mean distance:  726.9117911753777  threshold:  732.3999571095636
# test signature min distance:  637.9555178192501  mean distance:  718.5614594751628  threshold:  732.3999571095636
# test signature min distance:  562.1801304711793  mean distance:  662.1494038784184  threshold:  732.3999571095636
# test signature min distance:  625.8799806944808  mean distance:  715.3468435512441  threshold:  732.3999571095636
# test signature min distance:  651.3367717658496  mean distance:  753.17249576606  threshold:  732.3999571095636
# test signature min distance:  651.5294863949644  mean distance:  736.1379535566883  threshold:  732.3999571095636
# test signature min distance:  584.9700118631098  mean distance:  610.1980815681235  threshold:  732.3999571095636
# test signature min distance:  547.308031486756  mean distance:  640.2316676130287  threshold:  732.3999571095636
# test signature min distance:  522.749013085886  mean distance:  695.4819996717976  threshold:  732.3999571095636
# test signature min distance:  572.8774132244545  mean distance:  750.8649350643819  threshold:  732.3999571095636
# test signature min distance:  636.9207817127112  mean distance:  757.7557844491258  threshold:  732.3999571095636
# test signature min distance:  591.0796458712807  mean distance:  716.8637603494439  threshold:  732.3999571095636
# test signature min distance:  536.8817193681664  mean distance:  675.2059870816855  threshold:  732.3999571095636
# test signature min distance:  454.4174897625585  mean distance:  495.5349613543851  threshold:  732.3999571095636
# test signature min distance:  524.656855048715  mean distance:  682.1919878433993  threshold:  732.3999571095636
# test signature min distance:  545.9761098133941  mean distance:  684.5721856366036  threshold:  732.3999571095636
# test signature min distance:  482.61210057233586  mean distance:  654.5313345583551  threshold:  732.3999571095636
# test signature min distance:  510.14071147638003  mean distance:  690.4048739384795  threshold:  732.3999571095636
# test signature min distance:  508.35550421710406  mean distance:  636.9961193274863  threshold:  732.3999571095636
# test signature min distance:  552.9434716896079  mean distance:  688.2584537456851  threshold:  732.3999571095636
# test signature min distance:  474.4523537589982  mean distance:  524.8445840911729  threshold:  732.3999571095636
# test signature min distance:  462.15348702535107  mean distance:  499.50708272413436  threshold:  732.3999571095636
# test signature min distance:  435.17859859118454  mean distance:  486.9410662730398  threshold:  732.3999571095636
# test signature min distance:  577.4715558001924  mean distance:  624.0167791921364  threshold:  732.3999571095636
# test signature min distance:  713.3414171257957  mean distance:  738.3642626211849  threshold:  732.3999571095636
# test signature min distance:  727.5959086464311  mean distance:  760.1771703987488  threshold:  732.3999571095636
# test signature min distance:  780.4498817907948  mean distance:  815.9295955907737  threshold:  732.3999571095636
# test signature min distance:  690.2221809582184  mean distance:  702.8021963732805  threshold:  732.3999571095636
# test signature min distance:  814.234043183905  mean distance:  852.6709269967132  threshold:  732.3999571095636
# test signature min distance:  793.4924563977685  mean distance:  831.6852936398482  threshold:  732.3999571095636
# test signature min distance:  826.9823272694708  mean distance:  845.1466593952255  threshold:  732.3999571095636
# test signature min distance:  770.7363537966979  mean distance:  805.0339511348225  threshold:  732.3999571095636
# test signature min distance:  685.5666027308554  mean distance:  725.440078064315  threshold:  732.3999571095636
# test signature min distance:  748.0289514955941  mean distance:  800.7522063296609  threshold:  732.3999571095636
# test signature min distance:  781.9354359352112  mean distance:  804.6100807855838  threshold:  732.3999571095636
# test num: 62, accuracy: 80.64516129032258%
# FRR: 21.428571428571427%, FAR: 15.0%
# TOTAL_FRR: 8.333333333333332%, TOTAL_FAR: 8.75%, TOTAL_TEST_SIGN:4.0TOTAL_ACCU: 91.53225806451613%
#
#
# ['SIGN_GEN_USER5_USER5_1.csv', 'SIGN_GEN_USER5_USER5_2.csv', 'SIGN_GEN_USER5_USER5_3.csv', 'SIGN_GEN_USER5_USER5_4.csv', 'SIGN_GEN_USER5_USER5_5.csv', 'SIGN_GEN_USER5_USER5_6.csv', 'SIGN_GEN_USER5_USER5_7.csv', 'SIGN_GEN_USER5_USER5_8.csv', 'SIGN_GEN_USER5_USER5_9.csv', 'SIGN_GEN_USER5_USER5_10.csv', 'SIGN_GEN_USER5_USER5_11.csv', 'SIGN_GEN_USER5_USER5_12.csv', 'SIGN_GEN_USER5_USER5_13.csv', 'SIGN_GEN_USER5_USER5_14.csv', 'SIGN_GEN_USER5_USER5_15.csv']
# 193
# genuine signature distance:  206.86206146784696
# genuine signature distance:  314.4456075053241
# genuine signature distance:  296.22590535426644
# 离散系数: 0.17251800630470793
# 离散系数问题
# 193
# genuine signature distance:  228.796968232156
# genuine signature distance:  320.34572083052973
# genuine signature distance:  267.5618151918406
# 离散系数: 0.1378236791986823
# 离散系数问题
# 193
# genuine signature distance:  214.5025097090247
# genuine signature distance:  194.61092458758742
# genuine signature distance:  231.19884537829356
# 离散系数: 0.07007173392583535
# 14.955930563608355
# buffer选择的均值
# SIGN_GEN_USER5_USER5_1.csv
# SIGN_GEN_USER5_USER5_10.csv
# SIGN_GEN_USER5_USER5_12.csv
# SIGN_GEN_USER5_USER5_13.csv
# SIGN_GEN_USER5_USER5_16.csv
# SIGN_GEN_USER5_USER5_17.csv
# SIGN_GEN_USER5_USER5_18.csv
# SIGN_GEN_USER5_USER5_19.csv
# SIGN_GEN_USER5_USER5_2.csv
# SIGN_GEN_USER5_USER5_20.csv
# SIGN_GEN_USER5_USER5_21.csv
# SIGN_GEN_USER5_USER5_22.csv
# SIGN_GEN_USER5_USER5_23.csv
# SIGN_GEN_USER5_USER5_24.csv
# SIGN_GEN_USER5_USER5_25.csv
# SIGN_GEN_USER5_USER5_26.csv
# SIGN_GEN_USER5_USER5_27.csv
# SIGN_GEN_USER5_USER5_28.csv
# SIGN_GEN_USER5_USER5_29.csv
# SIGN_GEN_USER5_USER5_3.csv
# SIGN_GEN_USER5_USER5_30.csv
# SIGN_GEN_USER5_USER5_31.csv
# SIGN_GEN_USER5_USER5_32.csv
# SIGN_GEN_USER5_USER5_33.csv
# SIGN_GEN_USER5_USER5_34.csv
# SIGN_GEN_USER5_USER5_35.csv
# SIGN_GEN_USER5_USER5_36.csv
# SIGN_GEN_USER5_USER5_37.csv
# SIGN_GEN_USER5_USER5_38.csv
# SIGN_GEN_USER5_USER5_39.csv
# SIGN_GEN_USER5_USER5_4.csv
# SIGN_GEN_USER5_USER5_40.csv
# SIGN_GEN_USER5_USER5_41.csv
# SIGN_GEN_USER5_USER5_42.csv
# SIGN_GEN_USER5_USER5_43.csv
# SIGN_GEN_USER5_USER5_44.csv
# SIGN_GEN_USER5_USER5_45.csv
# SIGN_GEN_USER5_USER5_5.csv
# SIGN_GEN_USER5_USER5_6.csv
# SIGN_GEN_USER5_USER5_7.csv
# SIGN_GEN_USER5_USER5_8.csv
# SIGN_GEN_USER5_USER5_9.csv
# test_dfs_geni_num:42,:42
# SIGN_FOR_USER5_USER6_1.csv
# SIGN_FOR_USER5_USER6_2.csv
# SIGN_FOR_USER5_USER6_3.csv
# SIGN_FOR_USER5_USER6_4.csv
# SIGN_FOR_USER5_USER6_5.csv
# SIGN_FOR_USER5_USER7_10.csv
# SIGN_FOR_USER5_USER7_6.csv
# SIGN_FOR_USER5_USER7_7.csv
# SIGN_FOR_USER5_USER7_8.csv
# SIGN_FOR_USER5_USER7_9.csv
# SIGN_FOR_USER5_USER8_11.csv
# SIGN_FOR_USER5_USER8_12.csv
# SIGN_FOR_USER5_USER8_13.csv
# SIGN_FOR_USER5_USER8_14.csv
# SIGN_FOR_USER5_USER8_15.csv
# SIGN_FOR_USER5_USER9_16.csv
# SIGN_FOR_USER5_USER9_17.csv
# SIGN_FOR_USER5_USER9_18.csv
# SIGN_FOR_USER5_USER9_19.csv
# SIGN_FOR_USER5_USER9_20.csv
# test signature min distance:  284.97251424093605  mean distance:  311.6923927965797  threshold:  277.46865452579243
# test signature min distance:  179.52442838445592  mean distance:  186.49411008332436  threshold:  277.46865452579243
# test signature min distance:  193.3055265748676  mean distance:  195.82181701935352  threshold:  277.46865452579243
# test signature min distance:  224.90263640662687  mean distance:  232.50762208185233  threshold:  277.46865452579243
# test signature min distance:  234.7498215105049  mean distance:  250.0442597686125  threshold:  277.46865452579243
# test signature min distance:  210.92661904916972  mean distance:  216.7324213307137  threshold:  277.46865452579243
# test signature min distance:  227.41170323486665  mean distance:  248.00038904060682  threshold:  277.46865452579243
# test signature min distance:  253.14200068974594  mean distance:  259.64058307591694  threshold:  277.46865452579243
# test signature min distance:  271.1246435873539  mean distance:  296.9022284665095  threshold:  277.46865452579243
# test signature min distance:  206.32199158882128  mean distance:  210.66425855396054  threshold:  277.46865452579243
# test signature min distance:  226.75744338845269  mean distance:  243.02391460606032  threshold:  277.46865452579243
# test signature min distance:  207.00958524530293  mean distance:  230.62100498488203  threshold:  277.46865452579243
# test signature min distance:  215.3602676484875  mean distance:  225.42521104904233  threshold:  277.46865452579243
# test signature min distance:  215.84010402766964  mean distance:  224.60956754031852  threshold:  277.46865452579243
# test signature min distance:  248.07325217698443  mean distance:  280.64418886707796  threshold:  277.46865452579243
# test signature min distance:  282.72957473640093  mean distance:  291.7224126038352  threshold:  277.46865452579243
# test signature min distance:  236.15230021557127  mean distance:  272.65559978938876  threshold:  277.46865452579243
# test signature min distance:  276.87777660552206  mean distance:  281.9144143989931  threshold:  277.46865452579243
# test signature min distance:  240.18067052380945  mean distance:  265.18995219771875  threshold:  277.46865452579243
# test signature min distance:  244.5320687953422  mean distance:  250.88028892684977  threshold:  277.46865452579243
# test signature min distance:  273.1844261563991  mean distance:  277.3471753570045  threshold:  277.46865452579243
# test signature min distance:  287.4747629920675  mean distance:  295.71249046823397  threshold:  277.46865452579243
# test signature min distance:  237.72838937956521  mean distance:  247.51941056803287  threshold:  277.46865452579243
# test signature min distance:  225.74860807514636  mean distance:  234.61116531334415  threshold:  277.46865452579243
# test signature min distance:  216.53272914231016  mean distance:  224.2529400177681  threshold:  277.46865452579243
# test signature min distance:  228.1938495417583  mean distance:  239.8867777434904  threshold:  277.46865452579243
# test signature min distance:  233.87346893225893  mean distance:  252.98707637670486  threshold:  277.46865452579243
# test signature min distance:  247.04395982346654  mean distance:  282.1117368740166  threshold:  277.46865452579243
# test signature min distance:  212.435965394459  mean distance:  244.54033339763478  threshold:  277.46865452579243
# test signature min distance:  212.2871102714442  mean distance:  243.2248268598154  threshold:  277.46865452579243
# test signature min distance:  211.71210413570867  mean distance:  217.93090176478538  threshold:  277.46865452579243
# test signature min distance:  248.77162468287676  mean distance:  259.504901601838  threshold:  277.46865452579243
# test signature min distance:  261.12860207148714  mean distance:  263.4762230021709  threshold:  277.46865452579243
# test signature min distance:  232.08278697536454  mean distance:  243.0959773496936  threshold:  277.46865452579243
# test signature min distance:  240.93915131031952  mean distance:  258.0646226113026  threshold:  277.46865452579243
# test signature min distance:  215.3992989203455  mean distance:  219.81105477054052  threshold:  277.46865452579243
# test signature min distance:  232.00904895137674  mean distance:  250.22681226615177  threshold:  277.46865452579243
# test signature min distance:  206.3566547463353  mean distance:  214.39819111257933  threshold:  277.46865452579243
# test signature min distance:  242.50233805496703  mean distance:  248.62211778270202  threshold:  277.46865452579243
# test signature min distance:  214.47358503142226  mean distance:  217.30385857075794  threshold:  277.46865452579243
# test signature min distance:  189.18655465174245  mean distance:  204.35389268240704  threshold:  277.46865452579243
# test signature min distance:  184.1066585436568  mean distance:  195.529771012684  threshold:  277.46865452579243
# test num: 62, accuracy: 88.70967741935483%
# FRR: 16.666666666666664%, FAR: 0.0%
# TOTAL_FRR: 10.0%, TOTAL_FAR: 7.000000000000001%, TOTAL_TEST_SIGN:5.0TOTAL_ACCU: 90.96774193548387%
#
#
# ['SIGN_GEN_USER6_USER6_1.csv', 'SIGN_GEN_USER6_USER6_2.csv', 'SIGN_GEN_USER6_USER6_3.csv', 'SIGN_GEN_USER6_USER6_4.csv', 'SIGN_GEN_USER6_USER6_5.csv', 'SIGN_GEN_USER6_USER6_6.csv', 'SIGN_GEN_USER6_USER6_7.csv', 'SIGN_GEN_USER6_USER6_8.csv', 'SIGN_GEN_USER6_USER6_9.csv', 'SIGN_GEN_USER6_USER6_10.csv', 'SIGN_GEN_USER6_USER6_11.csv', 'SIGN_GEN_USER6_USER6_12.csv', 'SIGN_GEN_USER6_USER6_13.csv', 'SIGN_GEN_USER6_USER6_14.csv', 'SIGN_GEN_USER6_USER6_15.csv']
# 256
# genuine signature distance:  444.4724710610336
# genuine signature distance:  494.8545572005711
# genuine signature distance:  221.97627222313704
# 离散系数: 0.3062731988436181
# 离散系数问题
# 256
# genuine signature distance:  471.2910360668706
# genuine signature distance:  295.92958035776115
# genuine signature distance:  494.8545572005711
# 离散系数: 0.21094565450743882
# 离散系数问题
# 256
# genuine signature distance:  273.45524605056505
# genuine signature distance:  226.49671831439602
# genuine signature distance:  281.22023744534874
# 离散系数: 0.09284288979837149
# 24.175428215408605
# buffer选择的均值
# SIGN_GEN_USER6_USER6_1.csv
# SIGN_GEN_USER6_USER6_10.csv
# SIGN_GEN_USER6_USER6_11.csv
# SIGN_GEN_USER6_USER6_13.csv
# SIGN_GEN_USER6_USER6_15.csv
# SIGN_GEN_USER6_USER6_16.csv
# SIGN_GEN_USER6_USER6_17.csv
# SIGN_GEN_USER6_USER6_18.csv
# SIGN_GEN_USER6_USER6_19.csv
# SIGN_GEN_USER6_USER6_2.csv
# SIGN_GEN_USER6_USER6_20.csv
# SIGN_GEN_USER6_USER6_21.csv
# SIGN_GEN_USER6_USER6_22.csv
# SIGN_GEN_USER6_USER6_23.csv
# SIGN_GEN_USER6_USER6_24.csv
# SIGN_GEN_USER6_USER6_25.csv
# SIGN_GEN_USER6_USER6_26.csv
# SIGN_GEN_USER6_USER6_27.csv
# SIGN_GEN_USER6_USER6_28.csv
# SIGN_GEN_USER6_USER6_29.csv
# SIGN_GEN_USER6_USER6_3.csv
# SIGN_GEN_USER6_USER6_30.csv
# SIGN_GEN_USER6_USER6_31.csv
# SIGN_GEN_USER6_USER6_32.csv
# SIGN_GEN_USER6_USER6_33.csv
# SIGN_GEN_USER6_USER6_34.csv
# SIGN_GEN_USER6_USER6_35.csv
# SIGN_GEN_USER6_USER6_36.csv
# SIGN_GEN_USER6_USER6_37.csv
# SIGN_GEN_USER6_USER6_38.csv
# SIGN_GEN_USER6_USER6_39.csv
# SIGN_GEN_USER6_USER6_4.csv
# SIGN_GEN_USER6_USER6_40.csv
# SIGN_GEN_USER6_USER6_41.csv
# SIGN_GEN_USER6_USER6_42.csv
# SIGN_GEN_USER6_USER6_43.csv
# SIGN_GEN_USER6_USER6_44.csv
# SIGN_GEN_USER6_USER6_45.csv
# SIGN_GEN_USER6_USER6_5.csv
# SIGN_GEN_USER6_USER6_6.csv
# SIGN_GEN_USER6_USER6_8.csv
# SIGN_GEN_USER6_USER6_9.csv
# test_dfs_geni_num:42,:42
# SIGN_FOR_USER6_USER10_16.csv
# SIGN_FOR_USER6_USER10_17.csv
# SIGN_FOR_USER6_USER10_18.csv
# SIGN_FOR_USER6_USER10_19.csv
# SIGN_FOR_USER6_USER10_20.csv
# SIGN_FOR_USER6_USER7_1.csv
# SIGN_FOR_USER6_USER7_2.csv
# SIGN_FOR_USER6_USER7_3.csv
# SIGN_FOR_USER6_USER7_4.csv
# SIGN_FOR_USER6_USER7_5.csv
# SIGN_FOR_USER6_USER8_10.csv
# SIGN_FOR_USER6_USER8_6.csv
# SIGN_FOR_USER6_USER8_7.csv
# SIGN_FOR_USER6_USER8_8.csv
# SIGN_FOR_USER6_USER8_9.csv
# SIGN_FOR_USER6_USER9_11.csv
# SIGN_FOR_USER6_USER9_12.csv
# SIGN_FOR_USER6_USER9_13.csv
# SIGN_FOR_USER6_USER9_14.csv
# SIGN_FOR_USER6_USER9_15.csv
# test signature min distance:  301.7643168028448  mean distance:  309.97399308940436  threshold:  338.5079541178009
# test signature min distance:  259.9886760828475  mean distance:  279.5804677956419  threshold:  338.5079541178009
# test signature min distance:  221.97627222313704  mean distance:  241.5960149004535  threshold:  338.5079541178009
# test signature min distance:  288.20830942653635  mean distance:  293.04650299482154  threshold:  338.5079541178009
# test signature min distance:  478.4658076567065  mean distance:  487.1303524216767  threshold:  338.5079541178009
# test signature min distance:  299.0581829325249  mean distance:  319.2365881202363  threshold:  338.5079541178009
# test signature min distance:  307.18091957108095  mean distance:  329.7812422354797  threshold:  338.5079541178009
# test signature min distance:  249.10780036812642  mean distance:  271.73731106861646  threshold:  338.5079541178009
# test signature min distance:  296.75358082556795  mean distance:  320.59402554612734  threshold:  338.5079541178009
# test signature min distance:  229.4770213686996  mean distance:  253.48918666598263  threshold:  338.5079541178009
# test signature min distance:  248.57451491436106  mean distance:  261.66575997544527  threshold:  338.5079541178009
# test signature min distance:  259.67091454058146  mean distance:  268.46055695421734  threshold:  338.5079541178009
# test signature min distance:  283.9769475745498  mean distance:  288.89251933644624  threshold:  338.5079541178009
# test signature min distance:  312.0290086419646  mean distance:  330.7128098573305  threshold:  338.5079541178009
# test signature min distance:  275.85946001531266  mean distance:  281.059457629753  threshold:  338.5079541178009
# test signature min distance:  265.58104114420405  mean distance:  286.4411358664414  threshold:  338.5079541178009
# test signature min distance:  323.84677178813615  mean distance:  339.4927185702915  threshold:  338.5079541178009
# test signature min distance:  296.48070714012323  mean distance:  311.841159641777  threshold:  338.5079541178009
# test signature min distance:  271.0794821998884  mean distance:  296.7795960560417  threshold:  338.5079541178009
# test signature min distance:  336.1216907411991  mean distance:  344.9010547008436  threshold:  338.5079541178009
# test signature min distance:  257.8375210300845  mean distance:  260.74509410645936  threshold:  338.5079541178009
# test signature min distance:  260.59531348277113  mean distance:  280.8302038071517  threshold:  338.5079541178009
# test signature min distance:  412.9421594733177  mean distance:  435.6342601781066  threshold:  338.5079541178009
# test signature min distance:  229.46387220225444  mean distance:  259.51097302407703  threshold:  338.5079541178009
# test signature min distance:  311.0826542341524  mean distance:  331.1388350099592  threshold:  338.5079541178009
# test signature min distance:  348.01277508405843  mean distance:  357.74627905492724  threshold:  338.5079541178009
# test signature min distance:  278.09448590935506  mean distance:  306.0178529709764  threshold:  338.5079541178009
# test signature min distance:  345.9977863244561  mean distance:  353.63839904409934  threshold:  338.5079541178009
# test signature min distance:  276.26396874731887  mean distance:  297.91326073842896  threshold:  338.5079541178009
# test signature min distance:  348.7840211171938  mean distance:  357.23613927107493  threshold:  338.5079541178009
# test signature min distance:  334.19658485472564  mean distance:  345.490972022794  threshold:  338.5079541178009
# test signature min distance:  301.3893944272727  mean distance:  324.66868850386675  threshold:  338.5079541178009
# test signature min distance:  274.07075933191555  mean distance:  300.9122947664902  threshold:  338.5079541178009
# test signature min distance:  345.23406031534574  mean distance:  352.5518070417227  threshold:  338.5079541178009
# test signature min distance:  295.8601928222499  mean distance:  319.8833479510212  threshold:  338.5079541178009
# test signature min distance:  326.8203415122038  mean distance:  348.0671902165507  threshold:  338.5079541178009
# test signature min distance:  323.0982667982795  mean distance:  337.66369003534845  threshold:  338.5079541178009
# test signature min distance:  292.1493257332127  mean distance:  306.94971004615473  threshold:  338.5079541178009
# test signature min distance:  226.62094764948338  mean distance:  242.8546707724298  threshold:  338.5079541178009
# test signature min distance:  233.57626809603687  mean distance:  255.51500181648154  threshold:  338.5079541178009
# ...
# test signature min distance:  201.39778634133677  mean distance:  214.0968286607143  threshold:  290.1626071743518
# test signature min distance:  286.2613235462191  mean distance:  295.1908009339179  threshold:  290.1626071743518
# test signature min distance:  227.63888204027597  mean distance:  247.85878980072212  threshold:  290.1626071743518
# test signature min distance:  237.11131663474424  mean distance:  252.9261857480028  threshold:  290.1626071743518
# test signature min distance:  255.4334282017235  mean distance:  277.30276855384614  threshold:  290.1626071743518
# test signature min distance:  214.6234223409595  mean distance:  229.1841765654539  threshold:  290.1626071743518
# test signature min distance:  252.06969489881752  mean distance:  273.4361130122286  threshold:  290.1626071743518
# test signature min distance:  259.8305922972086  mean distance:  268.54099838545113  threshold:  290.1626071743518
# test signature min distance:  238.639184048997  mean distance:  255.04925577140898  threshold:  290.1626071743518
# test signature min distance:  273.5966537975754  mean distance:  278.35649381856564  threshold:  290.1626071743518
# test signature min distance:  267.727007472129  mean distance:  272.24429705884876  threshold:  290.1626071743518
# test signature min distance:  263.79397547984524  mean distance:  272.7467663435386  threshold:  290.1626071743518
# test signature min distance:  253.85787594151623  mean distance:  277.6496026611137  threshold:  290.1626071743518
# test signature min distance:  218.84954143536916  mean distance:  248.00878594428113  threshold:  290.1626071743518
# test signature min distance:  254.89631664389634  mean distance:  271.31051552553316  threshold:  290.1626071743518
# test signature min distance:  238.93766830962295  mean distance:  241.41460248835313  threshold:  290.1626071743518
# test signature min distance:  246.4386231273908  mean distance:  255.92331203175573  threshold:  290.1626071743518
# test signature min distance:  195.48160799744824  mean distance:  229.7694976589017  threshold:  290.1626071743518
# test signature min distance:  199.78046827038332  mean distance:  221.3213777810964  threshold:  290.1626071743518
# test signature min distance:  244.50872940635347  mean distance:  255.85243564484747  threshold:  290.1626071743518
# test signature min distance:  225.7057611784401  mean distance:  243.70494430374288  threshold:  290.1626071743518
# test signature min distance:  229.19107372811487  mean distance:  248.6456258543939  threshold:  290.1626071743518
# test signature min distance:  223.49332934522823  mean distance:  239.41933119152466  threshold:  290.1626071743518
# test signature min distance:  218.38477384629746  mean distance:  234.2779300559596  threshold:  290.1626071743518
# test signature min distance:  241.4647837811928  mean distance:  253.81484797755283  threshold:  290.1626071743518
# test signature min distance:  246.27476493429756  mean distance:  261.19914529322233  threshold:  290.1626071743518
# test signature min distance:  190.35721987496922  mean distance:  212.08982315483232  threshold:  290.1626071743518
# test signature min distance:  262.98559397206867  mean distance:  274.1395822183506  threshold:  290.1626071743518
# test signature min distance:  254.45169032756172  mean distance:  270.2158649384974  threshold:  290.1626071743518
# test signature min distance:  267.0987888084786  mean distance:  282.34744773114954  threshold:  290.1626071743518
# test signature min distance:  258.9751110010474  mean distance:  269.3997045978758  threshold:  290.1626071743518
# test signature min distance:  253.80898862123902  mean distance:  286.0135747468243  threshold:  290.1626071743518
# test signature min distance:  278.7190658477791  mean distance:  297.0145045715027  threshold:  290.1626071743518
# test signature min distance:  193.8320551078648  mean distance:  210.93982470482183  threshold:  290.1626071743518
# test signature min distance:  195.05474230233276  mean distance:  214.40094094001645  threshold:  290.1626071743518
# test signature min distance:  255.52575582699907  mean distance:  265.604517946769  threshold:  290.1626071743518
# test signature min distance:  212.76507292151913  mean distance:  216.26188402757256  threshold:  290.1626071743518
# test signature min distance:  317.22959182825696  mean distance:  328.7412098511674  threshold:  290.1626071743518
# test signature min distance:  330.76239914060386  mean distance:  334.1054514896334  threshold:  290.1626071743518
# test signature min distance:  303.2623487343909  mean distance:  315.12897445232414  threshold:  290.1626071743518
# test signature min distance:  328.35255260354245  mean distance:  338.7825591203805  threshold:  290.1626071743518
# test signature min distance:  358.5848469005779  mean distance:  367.6719904883042  threshold:  290.1626071743518
# test signature min distance:  322.230385205189  mean distance:  344.7373622158848  threshold:  290.1626071743518
# test signature min distance:  329.5961172642242  mean distance:  349.8390907949858  threshold:  290.1626071743518
# test signature min distance:  333.231419741177  mean distance:  362.47875532881864  threshold:  290.1626071743518
# test signature min distance:  377.4002553344701  mean distance:  392.0723694912661  threshold:  290.1626071743518
# test signature min distance:  315.72679788450796  mean distance:  334.8161426656133  threshold:  290.1626071743518
# test signature min distance:  264.79918315570575  mean distance:  281.42436292617435  threshold:  290.1626071743518
# test signature min distance:  345.8048844561858  mean distance:  358.7111726959759  threshold:  290.1626071743518
# test signature min distance:  309.18623623386503  mean distance:  333.1337293818746  threshold:  290.1626071743518
# test signature min distance:  311.29497663488013  mean distance:  342.0102163873217  threshold:  290.1626071743518
# test signature min distance:  353.0324093478998  mean distance:  366.4976432247765  threshold:  290.1626071743518
# test signature min distance:  337.0191474478677  mean distance:  354.5853155397281  threshold:  290.1626071743518
# test signature min distance:  323.83454563916285  mean distance:  342.3189792344861  threshold:  290.1626071743518
# test signature min distance:  382.8650163189692  mean distance:  399.4527544043935  threshold:  290.1626071743518
# test signature min distance:  386.4896900773924  mean distance:  409.21677086615136  threshold:  290.1626071743518
# test signature min distance:  368.077198195482  mean distance:  374.51404785248604  threshold:  290.1626071743518
# test num: 62, accuracy: 95.16129032258065%
# FRR: 4.761904761904762%, FAR: 5.0%
# TOTAL_FRR: 11.614401858304298%, TOTAL_FAR: 11.890243902439025%, TOTAL_TEST_SIGN:82.0TOTAL_ACCU: 88.29661683713611%
#
#
# ['SIGN_GEN_USER83_USER83_1.csv', 'SIGN_GEN_USER83_USER83_2.csv', 'SIGN_GEN_USER83_USER83_3.csv', 'SIGN_GEN_USER83_USER83_4.csv', 'SIGN_GEN_USER83_USER83_5.csv', 'SIGN_GEN_USER83_USER83_6.csv', 'SIGN_GEN_USER83_USER83_7.csv', 'SIGN_GEN_USER83_USER83_8.csv', 'SIGN_GEN_USER83_USER83_9.csv', 'SIGN_GEN_USER83_USER83_10.csv', 'SIGN_GEN_USER83_USER83_11.csv', 'SIGN_GEN_USER83_USER83_12.csv', 'SIGN_GEN_USER83_USER83_13.csv', 'SIGN_GEN_USER83_USER83_14.csv', 'SIGN_GEN_USER83_USER83_15.csv']
# 287
# genuine signature distance:  438.78815867084165
# genuine signature distance:  393.48213443021206
# genuine signature distance:  425.73583304861097
# 离散系数: 0.045409398778279056
# 19.041767282616053
# buffer选择的均值
# SIGN_GEN_USER83_USER83_1.csv
# SIGN_GEN_USER83_USER83_10.csv
# SIGN_GEN_USER83_USER83_11.csv
# SIGN_GEN_USER83_USER83_12.csv
# SIGN_GEN_USER83_USER83_14.csv
# SIGN_GEN_USER83_USER83_15.csv
# SIGN_GEN_USER83_USER83_16.csv
# SIGN_GEN_USER83_USER83_17.csv
# SIGN_GEN_USER83_USER83_18.csv
# SIGN_GEN_USER83_USER83_19.csv
# SIGN_GEN_USER83_USER83_2.csv
# SIGN_GEN_USER83_USER83_20.csv
# SIGN_GEN_USER83_USER83_21.csv
# SIGN_GEN_USER83_USER83_22.csv
# SIGN_GEN_USER83_USER83_23.csv
# SIGN_GEN_USER83_USER83_24.csv
# SIGN_GEN_USER83_USER83_25.csv
# SIGN_GEN_USER83_USER83_26.csv
# SIGN_GEN_USER83_USER83_27.csv
# SIGN_GEN_USER83_USER83_28.csv
# SIGN_GEN_USER83_USER83_29.csv
# SIGN_GEN_USER83_USER83_3.csv
# SIGN_GEN_USER83_USER83_30.csv
# SIGN_GEN_USER83_USER83_31.csv
# SIGN_GEN_USER83_USER83_32.csv
# SIGN_GEN_USER83_USER83_33.csv
# SIGN_GEN_USER83_USER83_34.csv
# SIGN_GEN_USER83_USER83_35.csv
# SIGN_GEN_USER83_USER83_36.csv
# SIGN_GEN_USER83_USER83_37.csv
# SIGN_GEN_USER83_USER83_38.csv
# SIGN_GEN_USER83_USER83_39.csv
# SIGN_GEN_USER83_USER83_40.csv
# SIGN_GEN_USER83_USER83_41.csv
# SIGN_GEN_USER83_USER83_42.csv
# SIGN_GEN_USER83_USER83_43.csv
# SIGN_GEN_USER83_USER83_44.csv
# SIGN_GEN_USER83_USER83_45.csv
# SIGN_GEN_USER83_USER83_5.csv
# SIGN_GEN_USER83_USER83_6.csv
# SIGN_GEN_USER83_USER83_7.csv
# SIGN_GEN_USER83_USER83_8.csv
# test_dfs_geni_num:42,:42
# SIGN_FOR_USER83_USER61_1.csv
# SIGN_FOR_USER83_USER61_2.csv
# SIGN_FOR_USER83_USER61_3.csv
# SIGN_FOR_USER83_USER61_4.csv
# SIGN_FOR_USER83_USER61_5.csv
# SIGN_FOR_USER83_USER62_10.csv
# SIGN_FOR_USER83_USER62_6.csv
# SIGN_FOR_USER83_USER62_7.csv
# SIGN_FOR_USER83_USER62_8.csv
# SIGN_FOR_USER83_USER62_9.csv
# SIGN_FOR_USER83_USER63_11.csv
# SIGN_FOR_USER83_USER63_12.csv
# SIGN_FOR_USER83_USER63_13.csv
# SIGN_FOR_USER83_USER63_14.csv
# SIGN_FOR_USER83_USER63_15.csv
# SIGN_FOR_USER83_USER64_16.csv
# SIGN_FOR_USER83_USER64_17.csv
# SIGN_FOR_USER83_USER64_18.csv
# SIGN_FOR_USER83_USER64_19.csv
# SIGN_FOR_USER83_USER64_20.csv
# test signature min distance:  446.04688301966667  mean distance:  477.48599824544016  threshold:  545.135987998188
# test signature min distance:  390.9986139793091  mean distance:  414.24647753930367  threshold:  545.135987998188
# test signature min distance:  399.5237349688307  mean distance:  427.5304119586787  threshold:  545.135987998188
# test signature min distance:  411.6064510025419  mean distance:  429.59666783219427  threshold:  545.135987998188
# test signature min distance:  393.8106677881388  mean distance:  423.0939252453523  threshold:  545.135987998188
# test signature min distance:  380.3926610072969  mean distance:  398.0016066102061  threshold:  545.135987998188
# test signature min distance:  494.34970259461346  mean distance:  502.8899858517835  threshold:  545.135987998188
# test signature min distance:  468.4022705606167  mean distance:  491.49366352774973  threshold:  545.135987998188
# test signature min distance:  429.32957921183714  mean distance:  434.1422123783954  threshold:  545.135987998188
# test signature min distance:  444.03787510699647  mean distance:  467.8738242891716  threshold:  545.135987998188
# test signature min distance:  357.06429998179175  mean distance:  381.94112060075986  threshold:  545.135987998188
# test signature min distance:  432.57843932122057  mean distance:  458.7931293828933  threshold:  545.135987998188
# test signature min distance:  446.4224829891597  mean distance:  500.4940071990989  threshold:  545.135987998188
# test signature min distance:  444.2426042121719  mean distance:  465.87637258353817  threshold:  545.135987998188
# test signature min distance:  472.00093298024467  mean distance:  486.1579058654982  threshold:  545.135987998188
# test signature min distance:  438.45309330714747  mean distance:  461.28002468804397  threshold:  545.135987998188
# test signature min distance:  469.0606128957579  mean distance:  478.92560549667974  threshold:  545.135987998188
# test signature min distance:  526.9036444887294  mean distance:  546.0589050834743  threshold:  545.135987998188
# test signature min distance:  555.9570753053706  mean distance:  563.9542216849719  threshold:  545.135987998188
# test signature min distance:  486.06307172623167  mean distance:  493.0282348715198  threshold:  545.135987998188
# test signature min distance:  490.87068276581726  mean distance:  517.8054956179028  threshold:  545.135987998188
# test signature min distance:  450.3107928328753  mean distance:  480.5923478259426  threshold:  545.135987998188
# test signature min distance:  513.3956867916937  mean distance:  525.9134420166578  threshold:  545.135987998188
# test signature min distance:  381.37849199987164  mean distance:  417.38829241719924  threshold:  545.135987998188
# test signature min distance:  403.7900428060739  mean distance:  453.34805391428563  threshold:  545.135987998188
# test signature min distance:  366.1436075611954  mean distance:  424.84631436557873  threshold:  545.135987998188
# test signature min distance:  425.53334666519487  mean distance:  441.0593329214209  threshold:  545.135987998188
# test signature min distance:  394.9416513775132  mean distance:  423.2314141697098  threshold:  545.135987998188
# test signature min distance:  445.876578443299  mean distance:  471.1838876482866  threshold:  545.135987998188
# test signature min distance:  460.2223723497259  mean distance:  490.2370934314826  threshold:  545.135987998188
# test signature min distance:  400.4086537662819  mean distance:  407.09020597215317  threshold:  545.135987998188
# test signature min distance:  532.7137571449567  mean distance:  566.921235850548  threshold:  545.135987998188
# test signature min distance:  443.1920394016025  mean distance:  473.2113003018399  threshold:  545.135987998188
# test signature min distance:  441.15499204224943  mean distance:  472.7754538722234  threshold:  545.135987998188
# test signature min distance:  442.227574515189  mean distance:  457.3647063612212  threshold:  545.135987998188
# test signature min distance:  420.77270844987953  mean distance:  430.69460553679164  threshold:  545.135987998188
# test signature min distance:  372.35433628679846  mean distance:  389.35846884563693  threshold:  545.135987998188
# test signature min distance:  433.79067612434363  mean distance:  439.9965491497494  threshold:  545.135987998188
# test signature min distance:  405.0319468854399  mean distance:  411.25359304432595  threshold:  545.135987998188
# test signature min distance:  390.0388032739921  mean distance:  406.1251365955281  threshold:  545.135987998188
# test signature min distance:  378.0627451588284  mean distance:  405.87809598524194  threshold:  545.135987998188
# test signature min distance:  395.36723357364366  mean distance:  408.8513807078588  threshold:  545.135987998188
# test signature min distance:  674.7729123925149  mean distance:  695.3204543423609  threshold:  545.135987998188
# test signature min distance:  590.6786018741772  mean distance:  611.9030894784323  threshold:  545.135987998188
# test signature min distance:  613.7852859580739  mean distance:  646.4510745270849  threshold:  545.135987998188
# test signature min distance:  559.0032368558462  mean distance:  590.136811310881  threshold:  545.135987998188
# test signature min distance:  517.351632659575  mean distance:  553.0713642951669  threshold:  545.135987998188
# test signature min distance:  523.2935674385816  mean distance:  535.1636077271114  threshold:  545.135987998188
# test signature min distance:  514.5950984608942  mean distance:  532.1015586916486  threshold:  545.135987998188
# test signature min distance:  526.1272552272619  mean distance:  541.4985977096386  threshold:  545.135987998188
# test signature min distance:  494.7997148298274  mean distance:  530.3754657145965  threshold:  545.135987998188
# test signature min distance:  544.2453077431916  mean distance:  565.8511692036542  threshold:  545.135987998188
# test signature min distance:  573.6838678277685  mean distance:  596.1138996322375  threshold:  545.135987998188
# test signature min distance:  619.0868997874999  mean distance:  643.8305237197487  threshold:  545.135987998188
# test signature min distance:  580.270240732711  mean distance:  607.761507428398  threshold:  545.135987998188
# test signature min distance:  567.1719290555512  mean distance:  607.503739187003  threshold:  545.135987998188
# test signature min distance:  533.4421648401924  mean distance:  556.8504266145263  threshold:  545.135987998188
# test num: 62, accuracy: 88.70967741935483%
# FRR: 7.142857142857142%, FAR: 20.0%
# TOTAL_FRR: 11.560527825588068%, TOTAL_FAR: 11.987951807228916%, TOTAL_TEST_SIGN:83.0TOTAL_ACCU: 88.30159347065683%
